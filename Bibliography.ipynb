# %%
# %%javascript
# IPython.load_extensions('calico-spell-check', 'calico-document-tools', 'calico-cell-tools');

# %%
<!--bibtex
Automatically generated by Mendeley Desktop 1.13.8
Any changes to this file will be lost if it is regenerated by Mendeley.

BibTeX export options can be customized via Options -> BibTeX in Mendeley Desktop

@article{Crutchfield1994,
abstract = {Defining structure and detecting the emergence of complexity in nature are inherently subjective, though essential, scientific activities. Despite the difficulties, these problems can be analyzed in terms of how model-building observers infer from measurements the computational capabilities embedded in nonlinear processes. An observer’s notion of what is ordered, what is random, and what is complex in its environment depends directly on its computational resources: the amount of raw measurement data, of memory, and of time available for estimation and inference. The discovery of structure in an environment depends more critically and subtlely, though, on how those resources are organized. The descriptive power of the observer’s chosen (or implicit) computational model class, for example, can be an overwhelming determinant in finding regularity in data. This paper presents an overview of an inductive framework — hierarchical -machine reconstruction — in which the emergence of complexity is associated with the innovation of new computational model classes. Complexity metrics for detecting structure and quantifying emergence, along with an analysis of the constraints on the dynamics of innovation, are outlined. Illustrative examples are drawn from the onset of unpredictability in nonlinear systems, finitary nondeterministic processes, and cellular automata pattern recognition. They demonstrate how finite inference resources drive the innovation of new structures and so lead to the emergence of complexity.},
author = {Crutchfield, James P.},
doi = {10.1016/0167-2789(94)90273-9},
file = {:D$\backslash$:/Mendeley/CalcEmerg.pdf:pdf},
isbn = {0167-2789},
issn = {01672789},
journal = {Physica D: Nonlinear Phenomena},
number = {1-3},
pages = {11--54},
pmid = {308},
title = {{The calculi of emergence: computation, dynamics and induction}},
volume = {75},
year = {1994}
}
@article{Hunte,
author = {Hunte, Garth S and Wears, Robert L and Schubert, Christiane C},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Hunte, Wears - Unknown - Structure , Agency , and Resilience 1 INTRODUCTION 2 STRUCTURE AND AGENCY.pdf:pdf},
journal = {REA Conference},
keywords = {complexity,resilience,sociotechnical systems},
mendeley-tags = {complexity,resilience,sociotechnical systems},
pages = {1--8},
title = {{Structure , Agency , and Resilience}}
}
@article{Fiksel2006,
author = {Fiksel, Joseph},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Fiksel - 2006 - SSPP Sustainability and resilience toward a systems approach.pdf:pdf},
keywords = {0608-028,14,2,2006,21,appropriate technology,archives,biocomplexity,citation,com,decision models,ecosystem analysis,environment relationship,fiksel,globalization,html,http,j,policy 2,population-,practice,proquest,science,sspp,sustainability,sustainability and resilience,toward a systems approach,vol2iss2},
number = {2},
pages = {14--21},
title = {{SSPP: Sustainability and resilience: toward a systems approach}},
volume = {2},
year = {2006}
}
@article{Ad,
author = {Ad, R},
file = {:D$\backslash$:/Mendeley/Unknown - Unknown - Handbook of Jacobians.pdf:pdf},
title = {{Handbook of Jacobians}}
}
@article{Rittel1973,
abstract = {we are calling them "wicked," not because these properties are themselves ethically deplorable. We use the term "wicked" in a meaning akin to that of "malignant" (in contrast to "benign") or "vicious" (like a circle) or "tricky" (like a leprechaun) or "aggressive" (like a lion, in contrast to the docility of a lamb) 1- There is no definitive formulation of a wicked problem 2. Wicked problems have no stopping rule 3. Solutions to wicked problems are not true-or-false but good-or-bad 4. There is no immediate and no ultimate test of a solution to a wicked problem 5. Every solution to ,a wicked problem is a "one-shot operation" because there is no opportunity to learn by trial-and-error, every attempt counts significantly 6. Wicked problems do not have an enumerable (or an exhaustively describable set of potential solutions nor is there a well-described set of permissible operations that may be incorporated into the plan. 7. Every wicked problem is essentially unique 8. Every wicked problem can be considered to be a symptom of another problem 9. The existence of a discrepancy representing a wicked problem can be explained in numerous ways The choice of explanation determines the nature of the problem's resolution 10. The planner has no right to be wrong.},
author = {Rittel, H.W.J. and Webber, M.M.},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Rittel, Webber - 1973 - Dilemnas in a general theory of planning.pdf:pdf},
journal = {Policy Sciences},
keywords = {design theory,resilience,reslience},
mendeley-tags = {design theory,resilience,reslience},
number = {December 1969},
pages = {155--169},
title = {{Dilemnas in a general theory of planning}},
volume = {4},
year = {1973}
}
@article{Biancolini2006,
abstract = {In this paper, a new acoustic emission (AE) diagnostic technique, for the study of fatigue cracks nucleation and propagation on steel, was investigated. Using the fractal analysis, and the box-counting method (BCM) in particular, it is possible to characterize the spatial distribution of the prime AE sources through the fractal dimension (D) that evolve with the number of fatigue cycles (N) of the specimen. D-N curves were found useful to identify the condition of incipient collapse due to the nucleation and propagation of fatigue cracks on steel. It is possible to use the fractal dimension as a damage parameter. In all tested specimens, the crisis occurs within the same range of values of fractal dimension. The results suggest that it is possible to anticipate the detection of crack beginning relating to the other theoretical or experimental techniques. ?? 2006 Elsevier Ltd. All rights reserved.},
author = {Biancolini, M. E. and Brutti, C. and Paparo, G. and Zanini, a.},
doi = {10.1016/j.ijfatigue.2005.12.003},
file = {:D$\backslash$:/Mendeley/Biancolini et al. - 2006 - Fatigue cracks nucleation on steel, acoustic emission and fractal analysis.pdf:pdf},
issn = {01421123},
journal = {International Journal of Fatigue},
keywords = {Acoustic emission,Crack nucleation,Fatigue,Fractal},
number = {12},
pages = {1820--1825},
title = {{Fatigue cracks nucleation on steel, acoustic emission and fractal analysis}},
volume = {28},
year = {2006}
}
@article{Fiksel2003,
abstract = {Pursuit of sustainable development requires a systems approach to the design of industrial product and service systems. Although many business enterprises have adopted sustainability goals, the actual development of sustainable systems remains challenging because of the broad range of economic, environmental and social factors that need to be considered across the system life cycle. Traditional systems engineering practices try to anticipate and resist disruptions but may be vulnerable to unforeseen factors. An alternative is to design systems with inherent "resilience" bytaking advantage of fundamental properties such as diversity, efficiency, adaptability, and cohesion. Previous work on sustainable design has focused largely upon ecological efficiency improvements. For example, companies have found that reducing material and energy intensity and converting wastes into valuable secondary products creates value for shareholders as well as for society at large. To encourage broader systems thinking, a design protocol is presented that involves the following steps: identifying system function and boundaries, establishing requirements, selecting appropriate technologies, developing a system design, evaluating anticipated performance, and devising a practical means for system deployment. The approach encourages explicit consideration of resilience in both engineered systems and the larger systems in which they are embedded.},
author = {Fiksel, Joseph},
doi = {10.1021/es0344819},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Fiksel - 2003 - Designing Resilient, Sustainable Systems.pdf:pdf},
isbn = {0013-936X},
issn = {0013936X},
journal = {Environmental Science and Technology},
number = {23},
pages = {5330--5339},
pmid = {14700317},
title = {{Designing Resilient, Sustainable Systems}},
volume = {37},
year = {2003}
}
@article{Harsanyi1995,
abstract = {Metals can exhibit dendritic short-circuits caused by
electrochemical migration in conductor-insulator structures, which may
result in failures and reliability problems in microcircuits. The
classical model of electrochemical migration has been well known for
several decades. This process is a transport of metal ions between two
metallization stripes under bias through a continuous aqueous
electrolyte. Due to the electrodeposition at the cathode, dendrites and
dendrite-like deposits are formed. Ultimately, such a deposit can lead
to a short circuit in the device and can clause catastrophic failure. A
few anomalous and newly discovered phenomena have initiated us to
perform some revisions and to add supplementary models to the
conventional one. A theoretical review based on practical results is
given about the most important possible processes. Material design
aspects are also discussed},
author = {Harsanyi, Gabor},
doi = {10.1109/95.465159},
file = {:D$\backslash$:/Mendeley/Harsanyi - 1995 - Electrochemical processes resulting in migrated short failures in microcircuits.pdf:pdf},
issn = {10709886},
journal = {IEEE transactions on components, packaging, and manufacturing technology. Part A},
number = {3},
pages = {602--610},
title = {{Electrochemical processes resulting in migrated short failures in microcircuits}},
volume = {18},
year = {1995}
}
@article{Francescotti2007,
abstract = {Here I offer a precise analysis of what it takes for a property to count as emergent. The features widely considered crucial to emergence include novelty, unpredictability, supervenience, relationality, and downward causal influence. By acknowledging each of these distinctive features, the definition provided below captures an important sense in which the whole can be more than the sum of its parts.},
author = {Francescotti, Robert Michael},
doi = {10.1007/s10670-007-9047-0},
file = {:D$\backslash$:/Mendeley/art\%3A10.1007\%2Fs10670-007-9047-0.pdf:pdf},
issn = {01650106},
journal = {Erkenntnis},
keywords = {Downward causation,Emergent properties,Novelty,Parts,Predictability,Relationality,Supervenience,Wholes},
number = {1},
pages = {47--63},
title = {{Emergence}},
volume = {67},
year = {2007}
}
@article{Kiessling1998,
abstract = {The distribution of eigenvalues of N times N random matrices in the limit N to infinity is the solution to a variational principle that determines the ground state energy of a confined fluid of classical unit charges. This fact is a consequence of a more general theorem, proven here, in the statistical mechanics of unstable interactions. Our result establishes the eigenvalue density of some ensembles of random matrices which were not covered by previous theorems.},
archivePrefix = {arXiv},
arxivId = {math-ph/9804006},
author = {Kiessling, Michael K. -H. and Spohn, Herbert},
doi = {10.1007/s002200050516},
eprint = {9804006},
file = {:D$\backslash$:/Mendeley/Kiessling, Spohn - 1999 - A Note on the Eigenvalue Density of Random Matrices.pdf:pdf},
issn = {0010-3616},
pages = {20},
primaryClass = {math-ph},
title = {{A Note on the Eigenvalue Density of Random Matrices}},
url = {http://arxiv.org/abs/math-ph/9804006},
volume = {695},
year = {1998}
}
@article{Longstaff2013,
author = {Longstaff, Patricia H and Koslowski, Thomas G and Geoghegan, Will},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Longstaff, Koslowski, Geoghegan - 2013 - Translating Resilience A Framework to Enhance Communication and Implementation.pdf:pdf},
journal = {5th International Symposium on Resilience Engineering},
keywords = {comparative,resilience},
mendeley-tags = {comparative,resilience},
title = {{Translating Resilience : A Framework to Enhance Communication and Implementation}},
year = {2013}
}
@article{Dwivedi2014,
author = {Dwivedi, Anurag},
doi = {10.1117/12.2054389},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Dwivedi - 2014 - Designing for resilience.pdf:pdf},
journal = {SPIE Defense + Security},
keywords = {critical infrastructure,criticality analysis,cyber attack,mission impact,resilience,risk,threat,vulnerability},
pages = {90970C},
title = {{Designing for resilience}},
url = {http://proceedings.spiedigitallibrary.org/proceeding.aspx?articleid=1883819},
volume = {9097},
year = {2014}
}
@article{Bachmann2007,
abstract = {An architectural tactic is a design decision that affects how well a software architecture addresses a particular quality attribute. This report describes how tactics are based on the parameters of quality attribute models. Tactics provide an architectural means of adjusting those parameters, which, in turn, can improve the quality-attribute-specific behavior of the resulting system. This report justifies the tactics for modifiability, using established concepts of coupling, cohesion, and cost motivations as the means of identifying parameters of interest. Various tactics are then described based on their ability to control these parameters. The report also describes a standard set of architectural patterns and their variants in terms of the use of these tactics.},
author = {Bachmann, Felix},
file = {:D$\backslash$:/Mendeley/Bachmann - 2007 - Modifiability Tactics.pdf:pdf},
journal = {Diauniroma3It},
keywords = {arch,architectural tactics,software architecture},
number = {September},
title = {{Modifiability Tactics}},
url = {http://oai.dtic.mil/oai/oai?verb=getRecord\&amp;metadataPrefix=html\&amp;identifier=ADA472581},
year = {2007}
}
@article{Griffith1921,
author = {Griffith, Author a a and Character, Physical and Griffith, By a a and Eng, M and Estcblishment, Aircraft},
file = {:D$\backslash$:/Mendeley/Griffith et al. - 2011 - The Phenomena of Rupture and Flow in Solids VI . The Phenomena of Rupture and Flow in Solids . larger question.pdf:pdf},
journal = {Philosophical Transactions of the Royal Society of London. Series A, Containing Papersof a Mathematical or Physical Character},
number = {1921},
pages = {163--198},
title = {{The Phenomena of Rupture and Flow in Solids VI . The Phenomena of Rupture and Flow in Solids . larger question of the nature of intermolecular cohesion . The original object of the work , which was carried out at the Royal Aircraft Estab- lishment , was t}},
volume = {221},
year = {1921}
}
@article{Yang2001,
abstract = {The fractal characteristics of dendrite and cellular structure of nickel-based superalloy K5 are investigated under directional solidification. Results show that the fractal dimension of the dendrite increases from 1.228 to 1.418 as the withdraw speeds change from 40 to 264 ??m/s, whereas the fractal dimension of the cellular changes little as the withdraw speeds from 600 to 952 ??m/s. The physical significance of the fractal dimension is analyzed by fractal theory. Based on this, a new idea is proposed that both the fractal dimension and the dendrite arm spacing or cellular spacing be considered to describe the evaluation of the solidification structure completely and integrally. ?? 2001 Elsevier Science Ltd. All rights reserved.},
author = {Yang, Aimin and Xiong, Yuhua and Liu, Lin},
doi = {10.1016/S1468-6996(01)00033-X},
file = {:D$\backslash$:/Mendeley/Yang, Xiong, Liu - 2001 - Fractal characteristics of dendrite and cellular structure in nickel-based superalloy at intermediate cooling.pdf:pdf},
isbn = {1468-6996},
issn = {14686996},
journal = {Science and Technology of Advanced Materials},
keywords = {Dendrite,Fractal dimension,Non-linear},
number = {1},
pages = {101--103},
title = {{Fractal characteristics of dendrite and cellular structure in nickel-based superalloy at intermediate cooling rate}},
volume = {2},
year = {2001}
}
@article{Wears2013,
author = {Wears, Robert L and Morrison, J Bradley},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Wears, Morrison - 2013 - Levels of Resilience Moving from Resilience to Resilience Engineering.pdf:pdf},
journal = {Proceedings of the 5th Resilience Engineering Symposium},
keywords = {engineering,resilience},
mendeley-tags = {engineering,resilience},
title = {{Levels of Resilience : Moving from Resilience to Resilience Engineering}},
year = {2013}
}
@article{Galante1993,
author = {Galante, G. and Lombardo, a. and Piacentini, M.},
doi = {10.1016/0890-6955(93)90089-D},
file = {:D$\backslash$:/Mendeley/Galante, Lombardo, Piacentini - 1993 - Fractal dimension A useful tool to describe the microgeometry of machined surfaces.pdf:pdf},
issn = {08906955},
journal = {International Journal of Machine Tools and Manufacture},
number = {4},
pages = {525--530},
title = {{Fractal dimension: A useful tool to describe the microgeometry of machined surfaces}},
volume = {33},
year = {1993}
}
@article{Wong2014,
author = {Wong, Connie and Odom, Samuel L and Hume, Kara and Cox, Ann W and Fettig, Angel and Kucharczyk, Suzanne and Brock, Matthew E and Plavnick, Joshua B and Fleury, Veronica P and Schultz, Tia R},
doi = {DOI 10.1007/s10803-014-2351-z},
file = {:D$\backslash$:/Mendeley/Wong et al. - 2014 - Evidence-Based Practices for Children , Youth , and Young Adults with Autism Spectrum Disorder.pdf:pdf},
issn = {1573-3432},
keywords = {ASD,Austism Spectrum Disorder,FPG Child Development Institute},
pages = {114},
pmid = {25578338},
title = {{Evidence-Based Practices for Children , Youth , and Young Adults with Autism Spectrum Disorder}},
year = {2014}
}
@article{Bishop2011,
abstract = {In applied sciences there is a tendency to rely on terminology that is either ill-defined or applied inconsistently across areas of research and application domains. Examples in informa- tion assurance include the terms resilience, robustness and survivability, where there exists subtle shades of meaning between researchers. These nuances can result in confusion and misinterpretations of goals and results, hampering com- munication and complicating collaboration. In this paper, we propose security-related definitions for these terms. Us- ing this terminology, we argue that research in these areas must consider the functionality of the system holistically, beginning with a careful examination of what we actually want the system to do. We note that much of the published research focuses on a single aspect of a system – availability – as opposed to the system’s ability to complete its function without disclosing confidential information or, to a lesser extent, with the correct output. Finally, we discuss ways in which researchers can explore resilience with respect to integrity, availability and confidentiality.},
author = {Bishop, Matt and Carvalho, Marco and Ford, Richard and Mayron, Liam M.},
doi = {10.1145/2073276.2073286},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Bishop et al. - 2011 - Resilience is More than Availability.pdf:pdf},
isbn = {9781450310789},
journal = {New Security Paradigms Workshop},
keywords = {Reliability,Robustness,Security metrics},
pages = {95--104},
title = {{Resilience is More than Availability}},
url = {http://nob.cs.ucdavis.edu/bishop/papers/2011-nspw/resilience.pdf},
year = {2011}
}
@article{Dauskardt1990,
abstract = {To examine the usefulness of the fractal concept in quantitative fractography, a series of classical fracture surfaces, namely transgranular cleavage, intergranular fracture, microvoid coalescence, quasicleavage and intergranular microvoid coalescence, are analyzed in terms of fractal geometry. Specifically, the five brittle and ductile fracture modes are studied, from three well characterized steels (a mild steel, a low-alloy steel and a 32 wt\% Mn-steel) where the salient microstructural dimensions contributing to the final fracture morphology have been measured. Resulting plots of the mean angular deviation, and Richardson (fractal) plots of the lineal roughness, as a function of the measuring step size, are interpreted with the aid of computer-simulated fracture-surface profiles with known characteristics. It is found that the ranges of resolution, over which the fractal dimension is constant, correspond to the pertinent metallurgical dimensions on the fracture surface, and thus can be related to microstructural size-scales.},
author = {Dauskardt, R.H. and Haubensak, F. and Ritchie, R.O.},
doi = {10.1016/0956-7151(90)90043-G},
file = {:D$\backslash$:/Mendeley/Dauskardt, Haubensak, Ritchie - 1990 - On the interpretation of the fractal character of fracture surfaces.pdf:pdf},
issn = {09567151},
journal = {Acta Metallurgica et Materialia},
number = {2},
pages = {143--159},
title = {{On the interpretation of the fractal character of fracture surfaces}},
volume = {38},
year = {1990}
}
@article{Hw2012,
author = {Hw, Emanuel Enre},
file = {:D$\backslash$:/Mendeley/Hw - 2012 - Emanuel ENRE 671 HW2.pdf:pdf},
pages = {5--7},
title = {{Emanuel ENRE 671 HW2}},
volume = {5},
year = {2012}
}
@article{Sandborn2003,
abstract = { Product sustainment means keeping an existing system operational and maintaining the ability to continue to manufacture and field versions of the system that satisfy the original requirements. Sustainment also includes manufacturing and fielding revised versions of the system that satisfy evolving requirements, which often requires the replacement of technologies used to construct the original system with newer technologies. Technology insertion involves determining which technologies to replace during a design refresh, i.e., deciding the design refresh content, and deciding when that design refresh should take place. Technology replacement decisions are driven by a broad range of issues including performance, reliability, environmental impact, cost, and logistics, and when, or if other design refreshes will take place. Traditional "value" metrics go part of the way toward providing a coupled view of performance, reliability and cost, but are generally ignorant of how product sustainment may be impacted. A metric that measures both the value of the technology refreshment and insertion, and its ability to support both the system's current and future affordability and capability needs including hardware, software, information and intellectual property is required. This paper discusses a concept called viability. Viability is a measure of the producibility, supportability, and evolvability of a system and can serve as a metric for assessing technology insertion opportunities.},
author = {Sandborn, Peter a. and Herald, Thomas E. and Houston, James and Singh, Pameet},
doi = {10.1109/TCAPT.2003.820984},
file = {:D$\backslash$:/Mendeley/Sandborn et al. - 2003 - Optimum Technology Insertion into Systems Based on the Assessment of Viability.pdf:pdf},
isbn = {15213331},
issn = {15213331},
journal = {IEEE Transactions on Components and Packaging Technologies},
keywords = {Bayesian decision network,Obsolescence,Sustainment,Technology insertion,Viability},
number = {4},
pages = {734--738},
title = {{Optimum technology insertion into systems based on the assessment of viability}},
volume = {26},
year = {2003}
}
@article{Herrera,
author = {Herrera, I a and Vennesland, A and Pasquini, A and Silvagni, S},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Herrera et al. - Unknown - Planning Measuring Resilience Potential and Early Warnings ( SCALES ) Combining Enterprise Architecture and R.pdf:pdf},
journal = {Resilience Engineering Association: 5th International Symposium},
number = {7465},
title = {{Planning Measuring Resilience Potential and Early Warnings ( SCALES ) Combining Enterprise Architecture and Resilience Engineering}},
url = {resilience; measurement}
}
@article{Sandborn2007,
author = {Sandborn, Peter a and Member, Senior and Mauro, Frank and Knox, Ron},
file = {:D$\backslash$:/Mendeley/Sandborn et al. - 2007 - Part Obsolescence Forecasting.pdf:pdf},
journal = {Packaging (Boston, Mass.)},
number = {3},
pages = {397--401},
title = {{Part Obsolescence Forecasting}},
volume = {30},
year = {2007}
}
@article{Bennett2003,
abstract = { As science and technology become increasingly sophisticated, government and industry are relying more and more on science's advanced methods to determine reliability. Unfortunately, political, economic, time, and other constraints imposed by the real world, inhibit the ability of researchers to calculate reliability efficiently and accurately. Because of such constraints, reliability must undergo an evolutionary change. The first step in this evolution is to re-interpret the concept so that it meets the new century's needs. The next step is to quantify reliability using both empirical methods and auxiliary data sources, such as expert knowledge, corporate memory, and mathematical modeling and simulation.},
author = {Bennett, Thomas R. and Booker, Jane M. and Keller-McNulty, Sallie and Singpurwalla, Nozer D.},
doi = {10.1109/TR.2002.807239},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Bennett et al. - 2003 - Testing the untestable Reliability in the 21st century.pdf:pdf},
issn = {00189529},
journal = {IEEE Transactions on Reliability},
keywords = {Belief functions,Decision making,Expert testimonies,Foundational issues in reliability,Possibility theory,Probability,Subjectivity},
number = {1},
pages = {118--124},
title = {{Testing the untestable: Reliability in the 21st century}},
volume = {52},
year = {2003}
}
@article{Weiping1997,
author = {Weiping, C and Chenghui, X U},
file = {:D$\backslash$:/Mendeley/Weiping, Chenghui - Unknown - Fractal structure of uniform corrosion surface for Fe-based alloys.pdf:pdf},
issn = {02618028},
journal = {Corrosion},
number = {2},
pages = {7--8},
title = {{Fractal structure of uniform corrosion surface for Fe-based alloys}},
volume = {6},
year = {1997}
}
@article{Salomon2014,
abstract = {Many real world optimization problems involve uncertainties. A solution for such a problem is expected to be robust to these uncertainties. Commonly, robustness is attained by choosing the solution’s parameters such that the solution’s performance is less influenced by negative effects of the uncertain parameters’ variations. This robustness may be viewed as a passive robustness, because once the solution’s parameters are chosen, the robustness is inherent in the solution and no further action, to suppress the effect of uncertainties, is expected. However, it is acknowledged that enhanced robustness comes on the expense of peak performances. In this study, Active Robust Optimization is presented as a new robust optimization approach. It considers products that are able to adapt to environmental changes. The enhanced robustness of these solutions is attained by adaptation, which reduces the loss in performance due to environmental changes. A new optimization problem named Active Robust Optimization Problem is formulated. The problem amalgamates robust optimization with dynamic optimization in order to evaluate the performance of a candidate solution, while considering possible environmental conditions. Adaptation’s influence on the solution’s performance and cost is considered as well. Hence, the problem is formulated as a multiobjective problem that simultaneously aims at low costs and high performance. Since these goals are commonly in conflict: the solution is a set of optimal adaptive solutions. An evolutionary algorithm is proposed in order to evolve this set. An example of optimizing an adaptive optical table is provided. It is shown that an adaptive product, which is an outcome of the suggested approach, may be superior to an equivalent product that is not adaptive.},
author = {Salomon, Shaul and Avigad, Gideon and Fleming, Peter J. and Purshouse, Robin C.},
doi = {10.1109/TCYB.2014.2304475},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Salomon et al. - 2014 - Active Robust Optimization Enhancing Robustness to Uncertain Environments.pdf:pdf},
issn = {21682267},
journal = {IEEE Transactions on Cybernetics},
number = {11},
pages = {2221--2231},
pmid = {25330479},
title = {{Active Robust Optimization: Enhancing Robustness to Uncertain Environments}},
volume = {44},
year = {2014}
}
@article{Grecco,
author = {Grecco, Cl\'{a}udio H S and Vidal, Mario C R and Cosenza, Carlos a N and Santos, Isaac J a L},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Grecco et al. - Unknown - A Fuzzy Model to Assess Resilience for Safety Management 1 INTRODUCTION 2 METHOD FOR RESILIENCE ASSESSMENT.pdf:pdf},
keywords = {resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
title = {{A Fuzzy Model to Assess Resilience for Safety Management 1 INTRODUCTION 2 METHOD FOR RESILIENCE ASSESSMENT}}
}
@article{Bouchaud2007,
abstract = {We present a general method to detect and extract from a finite time sample statistically meaningful correlations between input and output variables of large dimensionality. Our central result is derived from the theory of free random matrices, and gives an explicit expression for the interval where singular values are expected in the absence of any true correlations between the variables under study. Our result can be seen as the natural generalization of the Marcenko-Pastur distribution for the case of rectangular correlation matrices. We illustrate the interest of our method on a set of macroeconomic time series.},
archivePrefix = {arXiv},
arxivId = {physics/0512090},
author = {Bouchaud, J. P. and Laloux, L. and Miceli, M. a. and Potters, M.},
doi = {10.1140/epjb/e2006-00204-0},
eprint = {0512090},
file = {:D$\backslash$:/Mendeley/Bouchaud et al. - 2005 - Large dimension forecasting models and random singular value spectra.pdf:pdf},
issn = {14346028},
journal = {European Physical Journal B},
number = {2},
pages = {201--207},
primaryClass = {physics},
title = {{Large dimension forecasting models and random singular value spectra}},
volume = {55},
year = {2007}
}
@article{Worldwide2009,
author = {Worldwide, Automotive},
file = {:D$\backslash$:/Mendeley/Worldwide - 2009 - Mild Steels.pdf:pdf},
number = {August},
pages = {1--8},
title = {{Mild Steels}},
year = {2009}
}
@article{Kijima2010,
abstract = {This book describes the synthesis, characterization and applications of inorganic and metallic nanotubular materials. It cover a wide variety of nanotubular materials excluding carbon nanotubes, ranging from metal oxides, sulfides and nitrides such as titanium oxide, tungsten sulfide, and boron nitride, as well as platinum and other noble-metals to unique nanotubes consisting of water, graphen or fulleren. Based on their structural and compositional characteristics, these nanotubular materials are of importance for their potential applications in electronic devices, photocatalysts, dye-sensitized solar cells, nanothermometer, electrodes for fuel cells and batteries, sensors, and reinforcing fillers for plastics, among others. Such materials are also having a great impact on future developments, including renewable energy sources as well as highly efficient energy-conversion and energy-saving technologies. This book will be of particular interest to graduate students in chemistry and physics as well as experts in the fields of nanotechnology, material science and inorganic and solid-state chemistry.},
author = {Kijima, Tsuyoshi},
doi = {10.1007/978-3-642-03622-4},
file = {:D$\backslash$:/Mendeley/Sekino - 2010 - Inorganic and Metallic Nanotubular Materials.pdf:pdf},
isbn = {9783642036200},
issn = {03034216},
journal = {Topics in Applied Physics},
pages = {17--32},
title = {{Inorganic and Metallic Nanotubular Materials: Recent Technologies and Applications}},
volume = {117},
year = {2010}
}
@article{Yavari2002,
abstract = {In this paper we study the mechanical attributes of the fractal nature of fracture surfaces. The structure of stress and strain singularity at the tip of a fractal crack, which can be self-similar or self-affine, is studied. The three classical modes of fracture and the fourth mode of fracture are discussed for fractal cracks in twodimensional and three- dimensional solid bodies. It is discovered that there are six modes of fracture in fractal fracture mechanics. The J -integral is shown to be path-dependent. It is explained that the proposed modified J - integrals in the literature that are argued to be path-independent are only locally path-independent and have no physical meaning. It is conjectured that a fractal J -integral should be the rate of potential energy release per unit of a fractal measure of crack growth. The powers of stress and strain singularities at the tip of a fractal crack in a strain-hardening material are calculated. It is shown that stresses and strains have weaker singularities at the tip of a fractal crack than they do at the tip of a smooth crack.},
author = {Yavari, Arash and Sarkani, Shahram and Moyer, E. Thomas},
doi = {10.1023/A:1014878112730},
file = {:D$\backslash$:/Mendeley/Yavari, Sarkani, Jr - 2002 - The mechanics of self-similar and self-affine fractal cracks.pdf:pdf},
isbn = {0376-9429},
issn = {03769429},
journal = {International Journal of Fracture},
keywords = {Fractal crack,Fractal fracture,Fractal geometry},
number = {1},
pages = {1--27},
title = {{The mechanics of self-similar and self-affine fractal cracks}},
volume = {114},
year = {2002}
}
@article{Cagno2008,
abstract = {The growing complexity of modern society is fostering great attention to the issue of the continuity of critical services and related infrastructures. The underlying processes and physical components of a specific service delivery (e.g. electric power or water) reveal many dependencies both technical and non technical. The paper presents an integrated methodology for vulnerability and resilience analysis for underground infrastructures, i.e. a societal risk analysis of the failures of underground services for an urban area. Based on the use of a hybrid approach, the proposed methodology breaks down the area under analysis into sub-areas and assesses the dependencies among sub-areas both in terms of interoperability, damage propagation of critical infrastructures and target zoned-description. The methodology demonstrates clear advantage in terms of resilience analysis, more consistent with the “zoned” nature of failures of the underground infrastructures. A case study, dealing with the interoperability and damage propagation analysis of the underground infrastructures of a Northern Italy town, will be presented for this purpose. A resilience analysis of the “system of systems” (i.e. multiple underground infrastructures) can be performed through the proposed methodology, evaluating the internal characteristics of the system able to mitigate or amplify the impact of local failures and thus the capability to assure service continuity after such failures. Finally a strategy for risk mitigation is proposed in order to maintain the minimum level of service.},
author = {Cagno, Enrico and Grande, Ottavio and Trucco, Paolo},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Cagno, Grande, Trucco - 2008 - Towards an integrated vulnerability and resilience analysis for underground infrastructures.pdf:pdf},
journal = {3nd Resilience Engineering International Symposium},
keywords = {resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
title = {{Towards an integrated vulnerability and resilience analysis for underground infrastructures}},
url = {https://docs.google.com/a/wmu.se/file/d/0B2lfx\_f4ofuXYTZPd2ZZanlVenc/edit?usp=sharing},
year = {2008}
}
@article{Piaszczyk2011,
abstract = {This paper presents a methodology for Model Based Systems Engineering (MBSE) utilizing the guidelines provided by the Department of Defense Architectural Framework (DoDAF). MBSE focuses the system engineering process on system modeling. Thus, requirements derivation, system design, integration, verification, and validation activities all center around the model of the system. System models can be built in many ways. This paper presents an approach using DoDAF. Visual accessibility of the DoDAF views facilitates full participation by all system stakeholders, including the customers, developers, and implementers, and enables the necessary dialogue. The approach promotes communications among the members of the development team and speeds up the iterations of the systems engineering process. The paper illustrates the utility of the DoDAF artifacts by means of a simplified but comprehensive, easy to follow, illustrative example.},
author = {Piaszczyk, C},
doi = {10.1002/sys},
file = {:D$\backslash$:/Mendeley/Piaszczyk - 2011 - Model Based Systems Engineering with Department of Defense Architectural Framework.pdf:pdf},
issn = {1098-1241, 1098-1241},
journal = {Systems Engineering},
keywords = {52: Numerical Analysis, Simulation, and Modeling (,63: Mathematics and Computation (CE),63: Mathematics and Computation (MT),Mechanical \& Transportation Engineering Abstracts},
number = {4},
pages = {305--326},
title = {{Model Based Systems Engineering with Department of Defense Architectural Framework}},
url = {http://ezproxy.lib.ucf.edu/login?url=http://search.proquest.com/docview/926281441?accountid=10003$\backslash$nhttp://sfx.fcla.edu/ucf?url\_ver=Z39.88-2004\&rft\_val\_fmt=info:ofi/fmt:kev:mtx:journal\&genre=article\&sid=ProQ:ProQ:civilengineering\&atitle=Model+Based+Systems},
volume = {14},
year = {2011}
}
@article{VanderBeek2015,
author = {van der Beek, Dolf (F.a.) and Schraagen, Jan Maarten (J.M.C.)},
doi = {10.1016/j.ress.2015.03.019},
file = {:D$\backslash$:/Mendeley/1-s2.0-S095183201500085X-main.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
keywords = {Field study,Measurement instrument,Model development,Team resilience,Teamwork,measurement instrument},
pages = {1--12},
publisher = {Elsevier},
title = {{ADAPTER: Analysing \& Developing Adaptability \& performance in Teams to enhance resilience}},
url = {http://linkinghub.elsevier.com/retrieve/pii/S095183201500085X},
year = {2015}
}
@article{Gatheral2008,
author = {Gatheral, Jim},
file = {:D$\backslash$:/Mendeley/Gatheral - 2008 - and Covariance Estimation.pdf:pdf},
journal = {NYU Courant Institute Algorithmic Trading Conference},
title = {{Random matrix theory and covariance estimation}},
url = {http://bfi.cl/papers/Gatheral 2008 - Random matrix theory and covariance estimation.pdf},
year = {2008}
}
@article{Emanuel2011,
author = {Emanuel, Roy},
file = {:D$\backslash$:/Mendeley/Emanuel - 2011 - This information was entered into Weibull to get the plotting information.pdf:pdf},
title = {{This information was entered into Weibull ++ to get the plotting information}},
year = {2011}
}
@article{Lundberg2013,
author = {Lundberg, Jonas and Rankin, Amy},
doi = {10.1007/s10111-013-0253-z},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Lundberg, Rankin - 2013 - Resilience and vulnerability of small flexible crisis response teams implications for training and preparation.pdf:pdf},
issn = {14355558},
journal = {Cognition, Technology and Work},
keywords = {Crisis management,Improvisation,Resilience climate,Resilience engineering,Training,Vulnerability,design theory,reslience},
mendeley-tags = {design theory,reslience},
pages = {1--13},
title = {{Resilience and vulnerability of small flexible crisis response teams: implications for training and preparation}},
year = {2013}
}
@article{Balinski2007,
author = {Balinski, Michel and Laraki, Rida},
doi = {10.1073/pnas.0702634104},
file = {:D$\backslash$:/Mendeley/Balinski, Laraki - 2007 - A theory of measuring, electing, and ranking.pdf:pdf},
issn = {0027-8424},
journal = {Proceedings of the National Academy of Sciences of the United States of America},
pmid = {17496140},
title = {{A theory of measuring, electing, and ranking.}},
volume = {2007},
year = {2007}
}
@article{Saurin2012,
abstract = {The increasing interest in resilience engineering (RE) has led to a demand for frameworks that undertake safety assessments from such a standpoint. However, the few existing frameworks have drawbacks, such as not analyzing the sources of resilience (SRs) and the sources of brittleness (SBs) side-by-side. Moreover, they limit themselves to investigating resilience in pre-determined units of analysis (e.g., teams), neglecting the fact that resilience might be in any element of a socio-technical system. This article introduces a framework for identifying and analyzing SRs and SBs jointly, which do not constrain the identification process to any specific unit of analysis within the investigated system. The sources should be identified and analyzed across five categories: the opposite SR or SB; the risk from the SB; the effectiveness of the SR; those originating from either internal processes or the external environment; those arising from formal or informal practices. A case study of two air taxi carriers illustrates the application of the framework. Relevance to industry: Resilience engineering (RE) is an emerging safety management paradigm concerned with normal work, rather than emphasizing learning from incidents. The proposed framework allows the identification and analysis of the most salient sources of resilience and brittleness. It can be applied for investigating resilience at any unit of analysis within a socio-technical system, supporting the identification of strengths and weaknesses from the RE perspective. ?? 2011 Elsevier B.V.},
author = {Saurin, Tarcisio Abreu and {Carim Junior}, Guido Cesar},
doi = {10.1016/j.ergon.2011.12.001},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Saurin, Carim Junior - 2012 - A framework for identifying and analyzing sources of resilience and brittleness A case study of two air ta.pdf:pdf},
isbn = {01698141},
issn = {01698141},
journal = {International Journal of Industrial Ergonomics},
keywords = {Adaptations,Air taxi carriers,Brittleness,Complex systems,Resilience engineering,brittleness,case study,resilience},
mendeley-tags = {brittleness,case study,resilience},
number = {3},
pages = {312--324},
pmid = {73964569},
publisher = {Elsevier Ltd},
title = {{A framework for identifying and analyzing sources of resilience and brittleness: A case study of two air taxi carriers}},
url = {http://dx.doi.org/10.1016/j.ergon.2011.12.001},
volume = {42},
year = {2012}
}
@article{Golany2009,
abstract = {Probabilistic uncertainty is caused by "chance", whereas strategic uncertainty is caused by an adverse interested party. Using linear impact functions, the problems of allocating a limited resource to defend sites that face either probabilistic risk or strategic risk are formulated as optimization problems that are solved explicitly. The resulting optimal policies differ - under probabilistic risk, the optimal policy is to focus the investment of resources on priority sites where they yield the highest impact, while under strategic risk, the best policy is to spread the resources so as to decrease the potential damage level of the most vulnerable site(s). Neither solution coincides with the commonly practiced proportionality allocation scheme. ?? 2007 Elsevier B.V. All rights reserved.},
author = {Golany, Boaz and Kaplan, Edward H. and Marmur, Abraham and Rothblum, Uriel G.},
doi = {10.1016/j.ejor.2007.09.001},
file = {:D$\backslash$:/Mendeley/Golany et al. - 2009 - Nature plays with dice – terrorists do not Allocating resources to counter strategic versus probabilistic risks.pdf:pdf},
issn = {03772217},
journal = {European Journal of Operational Research},
keywords = {Game theory,Resource allocation,Risk analysis},
number = {1},
pages = {198--208},
title = {{Nature plays with dice - terrorists do not: Allocating resources to counter strategic versus probabilistic risks}},
volume = {192},
year = {2009}
}
@article{Emanuel2012,
author = {Emanuel, Roy},
file = {:D$\backslash$:/Mendeley/Emanuel - 2012 - Paperclip Experiment(2).pdf:pdf},
pages = {1--20},
title = {{Paperclip Experiment}},
year = {2012}
}
@article{Porter1998,
author = {Porter, Zell},
file = {:D$\backslash$:/Mendeley/Resolution, Redesign - Unknown - An Economic Method for Evaluating Electronic Component Obsolescence Solutions.pdf:pdf},
journal = {Boeing Information Space \& Defence Systems},
pages = {1--9},
title = {{An Economic Method for Evaluating Electronic Component Obsolescence Solutions}},
url = {http://scholar.google.com/scholar?hl=en\&btnG=Search\&q=intitle:An+Economic+Method+for+Evaluating+Electronic+Component+Obsolescence+Solutions\#0},
year = {1998}
}
@article{InConsult,
author = {InConsult},
file = {:D$\backslash$:/Mendeley/Unknown - Unknown - Risk Management Update ISO 31000 Overview and Implications for Managers Contents.pdf:pdf},
pages = {12},
title = {{Risk Management Update - ISO 31000 Overview and Implications for Managers}}
}
@article{Bazant2007,
abstract = {Carpinteri et al.'s discussion is very welcome for it gives an opportunity to clarify long-running disagreements on the problem of size effect, important to several engineering fields. However, the discussion misinterprets many points of Ba ant and Yavari's paper and attempts to raise new issues. This response presents recent experimental results contradicting applicability of Carpinteri's "multifractal scaling law" (MFSL), and refutes the discussers' arguments on their proposed concepts of "fractal mechanics", on the statistical size effect, on the validity of mathematical derivation of MFSL and its asymptotic slope, and on various other aspects of scaling of quasibrittle failure. © 2007 Elsevier Ltd. All rights reserved.},
author = {Ba\v{z}ant, Zden\v{e}k P. and Yavari, Arash},
doi = {10.1016/j.engfracmech.2007.02.026},
file = {:D$\backslash$:/Mendeley/Bazant, Yavari - 2007 - Response to A. Carpinteri, B. Chiaia, P. Cornetti and S. Puzzi’s Comments on “Is the cause of size effect on str.pdf:pdf},
issn = {00137944},
journal = {Engineering Fracture Mechanics},
number = {17},
pages = {2897--2910},
title = {{Response to A. Carpinteri, B. Chiaia, P. Cornetti and S. Puzzi's Comments on "Is the cause of size effect on structural strength fractal or energetic-statistical?"}},
volume = {74},
year = {2007}
}
@article{Agarwal2007,
author = {Agarwal, Manju and Gupta, Rashika},
doi = {10.1080/07408170600743920},
file = {:D$\backslash$:/Mendeley/Agarwal, Gupta - 2007 - Homogeneous redundancy optimization in multi-state series-parallel systems A heuristic approach.pdf:pdf},
issn = {0740-817X},
journal = {IIE Transactions},
keywords = {heuristic approach,multi-state,redundancy optimization,series-parallel system},
number = {3},
pages = {277--289},
title = {{Homogeneous redundancy optimization in multi-state series-parallel systems: A heuristic approach}},
volume = {39},
year = {2007}
}
@article{Dhs2008,
author = {Dhs, The and Gao, The and Move, Big},
file = {:D$\backslash$:/Mendeley/Dhs, Gao, Move - 2008 - Problem Set 1 ENDS The top-level goal of all the studies is to provide a location for safe research on FMD . Th.pdf:pdf},
number = {2007},
title = {{Problem Set 1 ENDS : The top-level goal of all the studies is to provide a location for safe research on FMD . This goal breaks down into safety and usefulness of the facilities . Safety is further broken down into security and risk minimization . MEANS :}},
volume = {1},
year = {2008}
}
@article{Arrow2011,
author = {Arrow, Kenneth J},
file = {:D$\backslash$:/Mendeley/53.5.941-973.pdf:pdf},
journal = {Medical Care},
number = {5},
pages = {941--973},
title = {{Th1E American}},
volume = {53},
year = {2011}
}
@article{Nemeth2011,
abstract = {Like other high hazard sectors, successful crisis response relies on a well-founded understanding of the work domain and the manner in which operators perceive and deal with obstacles to achieving goals. That understanding is essential to the development of information and communications technology (ICT) that are intended to support operator performance. While crises are uncommon in other high hazard sectors such as nuclear power generation and aviation, acute and ambulatory healthcare work encounters life-and-death crises daily. This makes healthcare a useful living laboratory to develop ICT in order to manage crises. This paper shows how healthcare organizations that continually deal with complex, uncertain, high-tempo operations can serve as a model to develop ICT that supports crisis management. We illustrate the results of using these methods through an example of cognitive systems engineering research that identifies ambulatory care risks to patients. We then describe multiple methods that can be used together to efficiently study complex, high hazard work settings. We conclude with an example of how it can support the development of a cognitive aid for diabetic care to support work in that setting.},
author = {Nemeth, Christopher and Wears, Robert L. and Patel, Sachin and Rosen, Greg and Cook, Richard},
doi = {10.1007/s10111-011-0174-7},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Nemeth et al. - 2011 - Resilience is not control Healthcare, crisis management, and ICT.pdf:pdf},
issn = {14355558},
journal = {Cognition, Technology and Work},
keywords = {Cognitive systems engineering,Communications technology,Healthcare,Information technology,Resilience,resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
number = {3},
pages = {189--202},
title = {{Resilience is not control: Healthcare, crisis management, and ICT}},
volume = {13},
year = {2011}
}
@article{Butler2005,
author = {Butler, John C. and Chebeskov, Alexander N. and Dyer, James S. and Edmunds, Thomas a. and Jia, Jianmin and Oussanov, Vladimir I.},
doi = {10.1287/inte.1040.0112},
file = {:D$\backslash$:/Mendeley/Butler et al. - 2005 - The United States and Russia Evaluate Plutonium Disposition Options with Multiattribute Utility Theory.pdf:pdf},
isbn = {9780511611308},
issn = {00922102},
journal = {Interfaces},
keywords = {Decision analysis: multiple criteria,Government: agencies},
number = {1},
pages = {88--101},
title = {{The United States and Russia evaluate plutonium disposition options with multiattribute utility theory}},
volume = {35},
year = {2005}
}
@article{Ramirez-Marquez2010,
author = {Ramirez-Marquez, Jos\'{e} Emmanuel and Rocco, Claudio M.},
doi = {10.1080/07408170903459984},
file = {:D$\backslash$:/Mendeley/Ramirez-Marquez, Rocco - 2010 - Evolutionary optimization technique for multi-state two-terminal reliability allocation in multi-objecti.pdf:pdf},
issn = {0740-817X},
journal = {IIE Transactions},
number = {8},
pages = {539--552},
title = {{Evolutionary optimization technique for multi-state two-terminal reliability allocation in multi-objective problems}},
volume = {42},
year = {2010}
}
@article{Chang1984,
author = {Chang, Roger and Goddard, a},
file = {:D$\backslash$:/Mendeley/Dimension, Working - 1984 - Elsevier Science Publishers Physics Publishing Division) B.V.pdf:pdf},
number = {6991},
pages = {311--320},
title = {{(North-Holland 0 Elsevier Science Publishers Physics Publishing Division) B.V.}},
volume = {144},
year = {1984}
}
@article{Herrmann2010,
author = {Herrmann, Jeffrey W.},
doi = {10.1115/1.4001902},
file = {:D$\backslash$:/Mendeley/Herrmann - 2010 - Progressive Design Processes and Bounded Rational Designers.pdf:pdf},
issn = {10500472},
journal = {Journal of Mechanical Design},
number = {8},
pages = {081005},
title = {{Progressive Design Processes and Bounded Rational Designers}},
volume = {132},
year = {2010}
}
@article{Statistics2009,
author = {Statistics, Mathematical},
file = {:D$\backslash$:/Mendeley/Statistics - 2009 - Who Solved the Secretary Problem Author ( s ) Thomas S . Ferguson Source Statistical Science , Vol . 4 , No . 3 (.pdf:pdf},
journal = {Statistics},
number = {3},
pages = {282--289},
title = {{Who Solved the Secretary Problem ? Author ( s ): Thomas S . Ferguson Source : Statistical Science , Vol . 4 , No . 3 ( Aug ., 1989 ), pp . 282-289 Published by : Institute of Mathematical Statistics Stable URL : http://www.jstor.org/stable/2245639}},
volume = {4},
year = {2009}
}
@article{Righi2015,
author = {Righi, Angela Weber and Saurin, Tarcisio Abreu and Wachs, Priscila},
doi = {10.1016/j.ress.2015.03.007},
file = {:D$\backslash$:/Mendeley/1-s2.0-S0951832015000654-main.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
keywords = {Resilience,Resilience engineering,Safety management,Systematic literature review,resilience engineering},
mendeley-tags = {Resilience},
pages = {1--11},
publisher = {Elsevier},
title = {{A systematic literature review of resilience engineering: Research areas and A research agenda proposal}},
url = {http://linkinghub.elsevier.com/retrieve/pii/S0951832015000654},
year = {2015}
}
@article{Sundstrom2008,
author = {Sundstr\"{o}m, Gunilla a and Hollnagel, Erik and Corp, Advanta Bank and Roads, Mckean and Box, P O and Antipolis, F- Sophia},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Sundstr\"{o}m et al. - 2008 - Modelling Risk in Financial Services Systems A Functional Risk Modelling Perspective.pdf:pdf},
journal = {System},
keywords = {resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
title = {{Modelling Risk in Financial Services Systems : A Functional Risk Modelling Perspective}},
year = {2008}
}
@book{Lisnianski2010,
address = {London},
annote = {Resilience is not mentioned at all in this book. That is a very good sign for me. Novel idea, but not particularly different. Polish the acorn},
author = {Lisnianski, Anatoly and Frenkel, Ilia and Ding, Yi},
file = {:D$\backslash$:/Mendeley/Lisnianski, Frenkel, Ding - 2010 - Multi-stat System Reliability Analysis and Optimization for Engineers and Industrial Managers.pdf:pdf},
isbn = {9781849963190},
pages = {1--403},
publisher = {Springer-Verlag},
title = {{Multi-state System Reliability Analysis and Optimization for Engineers and Industrial Managers}},
year = {2010}
}
@article{Levitin2001,
abstract = {This paper adapts the universal generating function method of
multistate system reliability analysis to incorporate common-cause
failures (CCF). An implicit 2-stage approach is used. In stage \#1, a
polynomial representation of system-output performance distribution is
obtained without considering system elements which are subject to CCF.
In stage \#2, the contribution of CCF is correctly included based on
information stored in vector-indicators that describe states of system
elements belonging to various common-cause groups. A straightforward
procedure is suggested for evaluating reliability functions of
nonrepairable series-parallel multistate systems with CCF. This
procedure allows the reliability functions to be obtained numerically.
Examples are given},
author = {Levitin, Gregory},
doi = {10.1109/24.983398},
file = {:D$\backslash$:/Mendeley/Levitin - 2001 - Incorporating common-cause failures into nonrepairable multistate series-parallel system analysis.pdf:pdf},
issn = {00189529},
journal = {IEEE Transactions on Reliability},
keywords = {Common-cause failure,Multistate system,Performance rate,Universal generating function},
number = {4},
pages = {380--388},
title = {{Incorporating common-cause failures into nonrepairable multistate series-parallel system analysis}},
volume = {50},
year = {2001}
}
@article{Madni2009,
abstract = {As systems continue to grow in size and complexity, they pose increasingly greater safety and risk management chal- lenges. Today when complex systems fail and mishaps occur, there is an initial tendency to attribute the failure to human error. Yet research has repeatedly shown that more often than not it is not human error but organizational factors that set up adverse conditions that increase the likelihood of system failure. Resilience engineering is concerned with building systems that are able to circumvent accidents through anticipation, survive disruptions through recovery, and grow through adaptation. This paper de- fines resilience from different perspectives, provides a conceptual framework for understanding and analyzing disruptions, and presents principles and heuristics based on lessons learned that can be employed to build resilient systems.},
author = {Madni, Azad M. and Jackson, Scott},
file = {:D$\backslash$:/Mendeley/Madni.pdf:pdf},
journal = {IEEE Systems Journal},
keywords = {Adaptive capacity,disruptions,resilience engi- neering,risk management.},
mendeley-tags = {Adaptive capacity,disruptions,resilience engi- neering,risk management.},
number = {2},
pages = {181--191},
title = {{Towards a conceptual framework for Resilience Engineering}},
volume = {3},
year = {2009}
}
@article{Xu2004,
author = {Xu, Hong and Dugan, Joanne Bechta and Ph, D},
file = {:D$\backslash$:/Mendeley/Xu, Dugan, Ph - Unknown - Combining Dynamic Fault Trees and Event Trees for Probabilistic Risk Assessment.pdf:pdf;:D$\backslash$:/Mendeley/Xu, Dugan, Ph - 2004 - Combining Dynamic Fault Trees and Event Trees for Probabilistic Risk Assessment.pdf:pdf},
isbn = {0780382153},
keywords = {and fault tree analysis,are used in probabilistic,as system analysis methodologies,both event tree analysis,conclusions,dynamic fault tree,eta,event tree,fta,markov chain,module,summary},
pages = {214--219},
title = {{Combining Dynamic Fault Trees and Event Trees for Probabilistic Risk Assessment}},
year = {2004}
}
@article{Lalouette2008,
abstract = {During a co-design project, we modeled formal and informal cooperation which are expressions of tight and loose couplings. Our findings confirm that loose couplings are crucial since they enable selforganization and emerging processes which often underlie success of codesign. We offer new insight into management and organization theories by presenting an inter-organizational resilience model which explains how non-deterministic couplings can enhance inter-organizational resilience},
author = {Lalouette, Colin and Pavard, Bernard},
file = {:D$\backslash$:/Mendeley/Lalouette\_Pavard\_text.pdf:pdf},
journal = {3nd Resilience Engineering International Symposium},
keywords = {resilience},
mendeley-tags = {resilience},
title = {{Enhancing inter-organizational resilience by loose coupling concept and complexity paradigm}},
url = {https://docs.google.com/a/wmu.se/file/d/0B2lfx\_f4ofuXYTB3SkE0YVdWYmM/edit?usp=sharing},
year = {2008}
}
@article{Edwards1977,
abstract = {Arguments over public policy typically turn out to hinge on disagreements about public values. Often, those in conflict may agree about what the relevant dimensions of value are. The conflicts arise over the relative importance of various goals. Normally, such disagreements are fought out in the contexts of specific decisions, and so are fought out over and over again, at enormous social cost each time another decision must be made. This paper proposes a method that can spell out explicitly what each individual's or group's values are, showing how and how much they differ-and in the process can frequently reduce the extent of such differences. It presents data illustrating the application of this technology, multiattribute utility measurement, to two specific instances: management of the coastal zone of the town of Venice, a part of Los Angeles, CA; and selection of research programs for the Office of Child Development, Department of Health, Education, and Welfare. In both cases, exploitation of multiattribute utility measurement permits the decisionmaking or regulatory agencies to shift their attention from the specific actions, being regulated to the values these actions serve and the decisionmaking mechanisms that implement these values. In the process, the data show that degree of disagreement about values among holders of conflicting value systems are often reduced.},
author = {Edwards, Ward},
doi = {10.1109/TSMC.1977.4309720},
file = {:D$\backslash$:/Mendeley/Edwards - 1977 - Fow to Use Multiattribute Utility Measurement for Social Decisionmaking.pdf:pdf},
isbn = {0018-9472},
issn = {0018-9472},
journal = {IEEE Transactions on Systems, Man, and Cybernetics},
number = {5},
pages = {326--340},
title = {{How to Use Multiattribute Utility Measurement for Social Decisionmaking}},
volume = {7},
year = {1977}
}
@article{Haukaas2011,
author = {Haukaas, T and Asce, M and Gardoni, P},
doi = {10.1061/(ASCE)EM.1943-7889.0000253.},
file = {:D$\backslash$:/Mendeley/Haukaas, Asce, Gardoni - 2011 - Model Uncertainty in Finite-Element Analysis Bayesian Finite Elements.pdf:pdf;:D$\backslash$:/Mendeley/Haukaas, Asce, Gardoni - 2011 - Model Uncertainty in Finite-Element Analysis Bayesian Finite Elements(2).pdf:pdf},
number = {August},
pages = {519--526},
title = {{Model Uncertainty in Finite-Element Analysis : Bayesian Finite Elements}},
year = {2011}
}
@article{Saurin,
abstract = {Resilience engineering (RE) has been widely promoted as a safety management paradigm particularly suitable for complex socio- technical systems (CSTSs). However, the reasons for that assumption have been often taken for granted. This paper contributes to the identification of the links between RE and the nature of CSTSs, by discussing three questions: (a) how do the characteristics of CSTSs affect the system´s resilience? (b) how does the guideline of creating an environment that supports resilience interact with other guidelines for managing CSTSs? (c) how are the characteristics of CSTSs affected by actions aimed at creating an environment that supports resilience?},
author = {Saurin, Tarcisio Abreu and Righi, Angela Weber},
file = {:D$\backslash$:/Mendeley/Saurin et al. (REA 2013). Characteristics of Complex Socio-Technical Systems and Guidelines for their Management the role of resilience.pdf:pdf},
journal = {Resilience Engineering Association: 5th International Symposium},
keywords = {resilience},
mendeley-tags = {resilience},
title = {{Characteristics of Complex Socio-Technical Systems and Guidelines for their Management : the role of resilience}}
}
@article{Warren2004,
author = {Warren, Lewis},
file = {:D$\backslash$:/Mendeley/Warren - Unknown - Uncertainties in the Analytic Hierarchy Process.pdf:pdf},
journal = {Information Sciences},
title = {{Uncertainties in the Analytic Hierarchy Process}},
url = {http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.86.6240\&amp;rep=rep1\&amp;type=pdf},
year = {2004}
}
@article{Carpinteri2004d,
abstract = {As is well-known, strength of materials is influenced by the specimen or structure size. In particular, several experimental campaigns have shown a decrease of the material strength under static or fatigue loading with increasing structural size, and some theoretical arguments have been proposed to interpret such a phenomenon. As far as fatigue crack growth is concerned, limited information on size effect is available in the literature. In the present paper, by exploiting some concepts of fractal geometry, new definitions of fracture energy and stress intensity factor based on physical dimensions different from the classical ones are discussed. Then, a size-dependent crack growth law (expressing crack growth rate against stress intensity factor range) is proposed. Finally, such a law is herein used to interpret relevant experimental data related to concrete. ?? 2003 Elsevier Ltd. All rights reserved.},
author = {Carpinteri, Andrea and Spagnoli, Andrea},
doi = {10.1016/S0142-1123(03)00142-7},
file = {:D$\backslash$:/Mendeley/Carpinteri, Spagnoli - 2004 - A fractal analysis of size effect on fatigue crack growth.pdf:pdf},
issn = {01421123},
journal = {International Journal of Fatigue},
keywords = {Concrete,Crack growth,Fatigue fracture phenomenon,Fractal geometry,Size effect},
number = {2},
pages = {125--133},
title = {{A fractal analysis of size effect on fatigue crack growth}},
volume = {26},
year = {2004}
}
@article{Shuman2002,
author = {Shuman, Luvenia L M and Major, Advisor and Carr, Bridget K and Air, Maxwell and Base, Force},
file = {:D$\backslash$:/Mendeley/Shuman et al. - 2002 - COST-BENEFIT ANALYSIS TOOLS FOR AVIONICS PARTS OBSOLESCENCE by A Research Report Submitted to the Faculty In Part.pdf:pdf},
journal = {Program},
number = {April},
title = {{COST-BENEFIT ANALYSIS TOOLS FOR AVIONICS PARTS OBSOLESCENCE by A Research Report Submitted to the Faculty In Partial Fulfillment of the Graduation Requirements Cost-Benefit Analysis Tools For Avionics Parts Obsolescence}},
year = {2002}
}
@article{Sandborn2004,
author = {Sandborn, Peter},
file = {:D$\backslash$:/Mendeley/Sandborn - 2004 - Beyond Reactive Thinking - We Should be Developing Pro-Active Approaches to Obsolescence Management Too!.pdf:pdf},
journal = {DMSMS Center of Excellence Newsletter},
number = {4},
title = {{Beyond reactive thinking–We should be developing pro-active approaches to obsolescence management too!}},
url = {http://enme.umd.edu/ESCML/Papers/ProactiveObsolescenceManagement.pdf},
volume = {2},
year = {2004}
}
@article{Linton2011,
abstract = {Since 2001, the Coast Guard's surface fleet has had a condition-based maintenance (CBM) policy. The reliability-centered maintenance (RCM) process is used to implement the policy by identifying minimum system maintenance requirements. The Coast Guard's RCMprogram provides the standards and capabilities needed to develop preventive maintenance systems that satisfy operational requirements. RCMrequirements are based on the industry standard SAE JA-1011, which provides evaluation criteria for RCM processes. Department of Defense (DoD) data-deliverable specifications, training programs, continuous improvement functions, information system requirements, and condition assessment programs complete the Coast Guard's RCMprogram. This paper discusses the genesis of the Coast Guard surface fleet's RCMprogram, how it is managed, and the benefits that it provides. © 2011, American Society of Naval Engineers.},
author = {Linton, Eric M.},
doi = {10.1111/j.1559-3584.2010.00294.x},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Linton - 2011 - Coast guard reliability-centered maintenance.pdf:pdf},
issn = {00281425},
journal = {Naval Engineers Journal},
number = {1},
pages = {25--30},
title = {{Coast guard reliability-centered maintenance}},
volume = {123},
year = {2011}
}
@article{Tao2011,
abstract = {This is a continuation of our earlier paper on the universality of the eigenvalues of Wigner random matrices. The main new results of this paper are an extension of the results in that paper from the bulk of the spectrum up to the edge. In particular, we prove a variant of the universality results of Soshnikov for the largest eigenvalues, assuming moment conditions rather than symmetry conditions. The main new technical observation is that there is a significant bias in the Cauchy interlacing law near the edge of the spectrum which allows one to continue ensuring the delocalization of eigenvectors.},
archivePrefix = {arXiv},
arxivId = {0908.1982},
author = {Tao, Terence and Vu, Van},
doi = {10.1007/s11511-011-0061-3},
eprint = {0908.1982},
file = {:D$\backslash$:/Mendeley/Tao, Vu - 1991 - Random matrices universality of local eigenvalue statistics.pdf:pdf},
isbn = {0001-5962},
issn = {00015962},
journal = {Acta Mathematica},
number = {1},
pages = {127--204},
title = {{Random matrices: Universality of local eigenvalue statistics}},
volume = {206},
year = {2011}
}
@article{Wears2006,
author = {Wears, Robert L and Perry, Shawna J},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Wears, Perry - 2006 - A Systems Dynamics Representation of Resilience 2 . 2 Guiding Principles for Model Development.pdf:pdf},
journal = {Resilience Engineering Association: 5th International Symposium},
keywords = {resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
title = {{A Systems Dynamics Representation of Resilience 2 . 2 Guiding Principles for Model Development}},
year = {2006}
}
@article{Overell2001,
abstract = {Suggests that managers should rely more on their intuition rather than on factual evidence, when making decisions. Contributions of intuitive consultants to businesses; Details on Praxis, the centre for developing personal effectiveness at Cranfield School of Management; Benefits of relying on intuition in business decision making.},
author = {Overell, Stephen},
file = {:D$\backslash$:/Mendeley/Bonabeau - Unknown - Trust Your Gut.pdf:pdf},
isbn = {00123242},
issn = {00123242},
journal = {Director},
keywords = {DECISION making,INDUSTRIAL management,INTUITION},
number = {12},
pages = {28},
title = {{Trust your gut}},
volume = {54},
year = {2001}
}
@article{Hurley1998,
author = {Hurley, W. J.},
doi = {10.1287/inte.28.6.19},
file = {:D$\backslash$:/Mendeley/Hurley - 2011 - Optimal Sequential Decisions and the Content of the Fourth-and-Goal.pdf:pdf},
issn = {0092-2102},
journal = {Interfaces},
number = {6},
pages = {19--22},
title = {{Optimal Sequential Decisions and the Content of the Fourth-and-Goal Conference}},
volume = {28},
year = {1998}
}
@article{Siegel2014,
author = {Siegel, Aron Wolf and Schraagen, Jan Maarten},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Siegel, Schraagen - 2014 - Developing resilience signals for the Dutch railway system.pdf:pdf},
journal = {5th Resilience Engineering Symposium},
keywords = {measurement,resilience},
mendeley-tags = {measurement,resilience},
number = {2009},
pages = {191--196},
title = {{Developing resilience signals for the Dutch railway system}},
year = {2014}
}
@article{Carpinteri2007,
abstract = {Aim of this letter to the Editor is at replying to the criticisms raised by Ba\v{z}ant and Yavari [Ba\v{z}ant ZP, Yavari A. Is the cause of size effect on structural strength fractal or energetic - statistical? Engng Fract Mech 2005;72:1-31] against the fractal approach to the size-scale effects on the mechanical properties of materials and the concept of the Multi-Fractal Scaling Law presented by Carpinteri [Carpinteri A. Scaling laws and renormalization groups for strength and toughness of disordered materials. Int J Solids Struct 1994;31:291-302]. These criticisms will be analysed thoroughly, showing how they also contain some mistakes and misunderstandings. The presented elucidations should redirect the discussion to a more correct scientific debate. © 2007 Elsevier Ltd. All rights reserved.},
author = {Carpinteri, Alberto and Chiaia, Bernardino and Cornetti, Pietro and Puzzi, Simone},
doi = {10.1016/j.engfracmech.2007.02.006},
file = {:D$\backslash$:/Mendeley/Carpinteri et al. - 2007 - Comments on “Is the cause of size effect on structural strength fractal or energetic-statistical” by Ba\v{z}ant \&.pdf:pdf},
issn = {00137944},
journal = {Engineering Fracture Mechanics},
keywords = {Fractals,Fracture energy,Size-scale effects,Strength},
number = {17},
pages = {2892--2896},
title = {{Comments on "Is the cause of size effect on structural strength fractal or energetic-statistical?" by Ba\v{z}ant \& Yavari [Engng Fract Mech 2005;72:1-31]}},
volume = {74},
year = {2007}
}
@phdthesis{Wears2011,
author = {Wears, Robert},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Wears - 2012 - Exploring the Dynamics of Resilient Performance Robert Wears l ’ \'{E}cole nationale sup\'{e}rieure des mines de Paris Sp\'{e}cialit\'{e}.pdf:pdf},
keywords = {resilience},
mendeley-tags = {resilience},
school = {\'{E}cole Nationale Sup\'{e}rieure des Mines de Paris},
title = {{Exploring the Dynamics of Resilient Performance}},
type = {Doctoral},
year = {2011}
}
@book{Aven2003,
address = {West Sussex},
author = {Aven},
isbn = {0-471-49548-4},
publisher = {John Wiley \& Sons Ltd},
title = {{Foundations of Risk Analysis}},
year = {2003}
}
@book{Simmons1985,
author = {Simmons, George F.},
editor = {Devine, Peter R. and Satloff, Jo},
isbn = {0-07-057419-7},
pages = {1--950},
publisher = {McGraw-Hill Inc.},
title = {{Calculus with Analytic Geometry}},
year = {1985}
}
@article{Grey2005,
author = {Grey, Cynthia J and Col, Lt and Smith, Advisor James M and Air, Maxwell and Base, Force},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Grey et al. - 2005 - AIR UNIVERSITY BLUES TO CIVVIES MORPHING THE MILITARY PROFESSION by A Research Report Submitted to Air Force Fello.pdf:pdf},
number = {April},
title = {{AIR UNIVERSITY BLUES TO CIVVIES : MORPHING THE MILITARY PROFESSION by A Research Report Submitted to Air Force Fellows , CADRE / AR In Partial Fulfillment of the Graduation Requirements USAF Academy , CO 80840 AU Advisor : Distribution A : Approved for Pu}},
year = {2005}
}
@article{Paul,
author = {Paul, M and Neville, A},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Paul, Neville - Unknown - Performance variability Black and white or shades of grey.pdf:pdf},
journal = {Resilience Engineering Association: 5th International Symposium},
keywords = {measurement,resilience},
mendeley-tags = {measurement,resilience},
title = {{Performance variability : Black and white or shades of grey ?}}
}
@article{Liang2006,
author = {Liang, Cheng-hao},
file = {:D$\backslash$:/Mendeley/Liang - 2006 - Pitting Corrosion Mechanisms and Characteristics of Aluminum in Solar Heating Systems.pdf:pdf},
isbn = {0086411889939},
journal = {Journal of the Chinese Chemical Society},
keywords = {aluminum,cl - ions,fractal,pitting corrosion},
pages = {313--318},
title = {{Pitting Corrosion Mechanisms and Characteristics of Aluminum in Solar Heating Systems}},
volume = {53},
year = {2006}
}
@book{Fromm,
author = {Fromm, Jochen and Fromm, Jochen},
file = {:D$\backslash$:/Mendeley/978-3-89958-069-3.volltext.frei.pdf:pdf},
isbn = {3899580699},
title = {{The Emergence of Complexity}}
}
@misc{Modarres2012,
address = {College Park, MD},
author = {Modarres, Mohammad and Kazemi, Reza},
title = {{ENRE 602 Reliability Analysis}},
year = {2012}
}
@article{Maryline2006,
abstract = {In this article we propose a theoretical discussion around the resilience concept and practice. Based upon a safety managerial trend aiming to diffuse safety culture through training within a pharmaceutical industry, analysis are initiated to define how organizational resilience (attached to safety culture) interweaves with risk factors and can be developed through training. Classical safety management aims at developing various systems, technical as well as organizational, to prevent and protect against dangers. Training, in this case, is a matter of risk assessment development. We suggest a new perspective stemming from human management. Its axis is to identify the frame of psychological resilience and to consider how it can be sustained. Psychological resilience appears to be a three-dimensional phenomenon less linked to risk assessment than to cultural structuralism and systemic adaptation. Along with the discussion, the question of training towards psychological resilience is discussed as well. It appears that resilience is questioned by uncertainty, ambiguity and complexity, and framed by structural, symbolic and relational systems; risk factors awareness, prudence and justice standards, along with systemic adaptation, altogether can sustain flexible and adaptative responses.},
author = {Maryline, Specht and Marc, Poumad\`{e}re},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Maryline, Marc - 2006 - Interrogating Resilience . Safety management , Social structuralism and Systemic adaptation .pdf:pdf},
journal = {2nd Resilience Engineering International Symposium},
keywords = {comparative,resilience},
mendeley-tags = {comparative,resilience},
number = {2006},
title = {{Interrogating Resilience . Safety management , Social structuralism and Systemic adaptation .}},
url = {https://docs.google.com/a/wmu.se/file/d/0B2lfx\_f4ofuXcWFlSld1MWl1ZFk/edit?usp=sharing},
year = {2006}
}
@article{Stogdill1999,
abstract = {The US Air Force has launched an initiative to develop an
affordable, systematic approach to dealing with obsolete electronic
parts. In addition to management and reengineering tools, the initiative
is developing reliability models for commercially manufactured
electronics used in defense systems},
author = {Stogdill, Ronald C.},
doi = {10.1109/54.765200},
file = {:D$\backslash$:/Mendeley/Stogdill - 1999 - Dealing with Obsolete Parts.pdf:pdf},
isbn = {0013791060},
issn = {07407475},
journal = {IEEE Design and Test of Computers},
number = {2},
pages = {17--25},
title = {{Dealing with obsolete parts}},
volume = {16},
year = {1999}
}
@article{Lay2015,
author = {Lay, E. and Branlat, M. and Woods, Z.},
doi = {10.1016/j.ress.2015.03.015},
file = {:D$\backslash$:/Mendeley/1-s2.0-S0951832015000812-main.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
keywords = {Resilience Engineering,Risk,System safety,resilience engineering},
pages = {1--11},
publisher = {Elsevier},
title = {{A Practitioner's Experiences Operationalizing Resilience Engineering}},
url = {http://linkinghub.elsevier.com/retrieve/pii/S0951832015000812},
year = {2015}
}
@article{Sutton2007,
author = {Sutton, Robert I and Staw, Barry M},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Sutton, Staw - 2007 - What Theory is Not What Theory is Not.pdf:pdf},
keywords = {resilience,theory building},
mendeley-tags = {resilience,theory building},
number = {3},
pages = {371--384},
title = {{What Theory is Not What Theory is Not}},
volume = {40},
year = {2007}
}
@book{Mckay,
author = {Mckay, Brett},
file = {:D$\backslash$:/Mendeley/AoM-30-Days.pdf:pdf},
isbn = {9780989190312},
title = {{30 Days to a Better Man}}
}
@article{Han2012,
abstract = {A System-of-Systems (SoS) is a collection of distributed independent individual systems that interact with one another to achieve an SoS capability requirement that cannot be achieved by individual systems alone (in contrast, in a monolithic system, hardware or software components are integrated to form a single entity). Interdependency between SoS systems, while enabling new capability, also means that failures can cascade throughout the SoS, creating development delays or additional system failures. Here we develop a method based on Bayesian networks to evaluate the resilience of SoS design alternatives to failures during operations. We propose a conditional resilience metric that measures each constituent system's contribution to overall SoS resilience, and a resilience pattern that shows how SoS performance degrades as systems fail. SoS resilience is determined by both the SoS architecture and the constituent system reliability. In a simple example based on the Littoral Combat Ship SoS, we determine the two most critical systems using the conditional resilience metric. Adding a communications link between these two systems increases the resilience, resulting in higher expected performance and slower expected performance degradation as a result of system failure. The conditional resilience and resilience pattern can be used by designers and other decision makers to identify SoS architectures and systems that increase SoS resilience to failure.},
author = {Han, Seung Yeob and Marais, Karen and DeLaurentis, Daniel},
doi = {10.1109/ICSMC.2012.6377904},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Han, Marais, DeLaurentis - 2012 - Evaluating system of systems resilience using interdependency analysis.pdf:pdf},
isbn = {9781467317146},
issn = {1062922X},
journal = {Conference Proceedings - IEEE International Conference on Systems, Man and Cybernetics},
keywords = {Bayesian Networks (BNs),Littoral Combat Ship (LCS),conditional probability,disruption,interdependency analysis,measurement,performance-failure diagram,resilience,system of systems (SoS)},
mendeley-tags = {measurement,resilience},
pages = {1251--1256},
title = {{Evaluating system of systems resilience using interdependency analysis}},
year = {2012}
}
@article{Pettit2010,
abstract = {In a world of turbulent change, resilience is a key competency since even the most carefully designed supply chain is susceptible to unforeseen events. This article presents a new Supply Chain Resilience Framework to help businesses deal with change. The conceptual framework is based on extant literature and refined through a focus group methodology. Our findings suggest that supply chain resilience can be assessed in terms of two dimensions: vulnerabilities and capabilities. The Zone of Resilience is defined as the desired balance between vulnerabilities and capabilities, where it is proposed that firms will be the most profitable in the long term. We identified seven vulnerability factors composed of 40 specific attributes and 14 capability factors from 71 attributes that facilitate the measurement of resilience. The article concludes with managerial implications and recommendations for future research.},
author = {Pettit, Timothy J and Fiksel, Joseph and Croxton, Keely L},
doi = {10.1002/j.2158-1592.2010.tb00125.x},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Pettit, Fiksel, Croxton - 2010 - Ensuring Supply Chain Resilience Development of a Conceptual Framework.pdf:pdf},
isbn = {07353766},
issn = {07353766},
journal = {Journal of Business Logistics},
number = {1},
pages = {1--21},
pmid = {49739125},
title = {{Ensuring Supply Chain Resilience: Development of a Conceptual Framework}},
url = {http://doi.wiley.com/10.1002/j.2158-1592.2010.tb00125.x},
volume = {31},
year = {2010}
}
@article{Meixell2001,
author = {Meixell, Mj and Wu, Sd},
file = {:D$\backslash$:/Mendeley/Meixell, Wu - 2001 - Market Using Leading Indicators.pdf:pdf},
journal = {Semiconductor Manufacturing, IEEE \ldots},
number = {1},
pages = {65--75},
title = {{Scenario analysis of demand in a technology market using leading indicators}},
url = {http://ieeexplore.ieee.org/xpls/abs\_all.jsp?arnumber=909656},
volume = {14},
year = {2001}
}
@article{Grøtan2008,
author = {Gr\o tan, To and St\o rseth, Fred},
file = {:D$\backslash$:/Mendeley/grotan\_storseth\_ro\_skjerve\_text.pdf:pdf},
journal = {\ldots on Resilience \ldots},
pages = {1--7},
title = {{Resilience, Adaptation and Improvisation–increasing resilience by organising for successful improvisation}},
url = {http://www.sintef-group.com/project/Building Safety/Publications/3rd RE symposium, resilience\_adaptation\_improvisation, TOG.pdf},
year = {2008}
}
@article{Gu2012,
abstract = {Reliability analysis considering multiple possible states is known as multi-state (MS) reliability analysis. Multi-state system reliability models allow both the system and its components to assume more than two levels of performance. Through multi-state reliability models provide more realistic and more precise representations of engineering systems, they are much more complex and present major difficulties in system definition and performance evaluation. MSS reliability has received a substantial amount of attention in the past four decades. This article presents a new and systematic review about multi-state system reliability. A timely review is an effective work related to improving the development of MSS theory. The review about the latest studies and advances about multi-state system reliability evaluation, multi-state systems optimization and multi-state systems maintenance is summarized in this paper. ?? 2011 Published by Elsevier Ltd.},
author = {Gu, Yingkui and Li, Jing},
doi = {10.1016/j.proeng.2011.12.756},
file = {:D$\backslash$:/Mendeley/1-s2.0-S1877705811065933-main.pdf:pdf},
issn = {18777058},
journal = {Procedia Engineering},
keywords = {Maintenance,Multi-state system,Optimization,Reliability evaluation},
pages = {531--536},
title = {{Multi-state system reliability: A new and systematic review}},
url = {http://dx.doi.org/10.1016/j.proeng.2011.12.756},
volume = {29},
year = {2012}
}
@article{Gelman2013a,
abstract = {Textbooks on statistics emphasize care and precision, via concepts such as reliability and validity in measurement, random sampling and treatment assignment in data collection, and causal identification and bias in estimation. But how do researchers decide what to believe and what to trust when choosing which statistical methods to use? How do they decide the credibility of methods? Statisticians and statistical practitioners seem to rely on a sense of anecdotal evidence based on personal experience and on the attitudes of trusted colleagues. Authorship, reputation, and past experience are thus central to decisions about statistical procedures.},
archivePrefix = {arXiv},
arxivId = {arXiv:1307.5929v1},
author = {Gelman, Andrew and Rourke, Keith O},
eprint = {arXiv:1307.5929v1},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Gelman, Rourke - 2013 - Convincing Evidence.pdf:pdf},
number = {June},
title = {{Convincing Evidence}},
year = {2013}
}
@article{Cattani2003,
abstract = {We study the effects of delaying an end-of-life buy. Manufacturers sometimes are required to place a final, end-of-life buy for a component that the supplier will no longer provide. The manufacturer performs a newsvendor analysis with the possible result of significant expected overage and underage costs. If the decision can be delayed, the expected overage and underage costs can be reduced. We model the effects of a delay of the final purchase under various scenarios of remaining demand. We contrast the manufacturing benefits with the costs incurred by the supplier and show that the supplier, who benefits greatly from the end-of-life buy, likely will require an incentive to enact a delay. Our results provide an insight to the observation of increasing numbers of end-of-life buys and provides a framework for analysis as manufacturers strive to cope with the issue. ?? 2002 Elsevier Science B.V. All rights reserved.},
author = {Cattani, Kyle D. and Souza, Gilvan C.},
doi = {10.1016/S0377-2217(02)00212-6},
file = {:D$\backslash$:/Mendeley/Cattani, Souza - 2003 - Good buy Delaying end-of-life purchases.pdf:pdf},
issn = {03772217},
journal = {European Journal of Operational Research},
keywords = {Inventory,Supply chain management},
number = {1},
pages = {216--228},
title = {{Good buy? Delaying end-of-life purchases}},
volume = {146},
year = {2003}
}
@article{Sandborn2011,
abstract = {Many technologies have life cycles that are shorter than the life cycle of the product or system they are in. Life cycle mismatches caused by the obsolescence of technology can result in large life cycle costs for long field life systems, such as aircraft, ships, communications infrastructure, power plant and grid management, and military systems. This paper addresses Diminishing Manufacturing Sources and Materials Shortages (DMSMS) obsolescence, which is defined as the loss of the ability to procure a technology or part from its original manufacturer. Forecasting when technologies and specific parts will become unavailable (non-procurable) is a key enabler for pro-active DMSMS management and strategic life cycle planning for long field life systems. This paper presents a methodology for generating algorithms that can be used to predict the obsolescence dates for electronic parts that do not have clear evolutionary parametric drivers. The method is based on the calculation of procurement lifetime using databases of previous obsolescence events and introduced parts that have not gone obsolete. The methodology has been demonstrated on a range of different electronic parts and for the trending of specific part attributes. ?? 2010 Elsevier Ltd. All rights reserved.},
author = {Sandborn, P. and Prabhakar, V. and Ahmad, O.},
doi = {10.1016/j.microrel.2010.08.005},
file = {:D$\backslash$:/Mendeley/ProcurementLifePaper.pdf:pdf},
issn = {00262714},
journal = {Microelectronics Reliability},
number = {2},
pages = {392--399},
title = {{Forecasting electronic part procurement lifetimes to enable the management of DMSMS obsolescence}},
volume = {51},
year = {2011}
}
@article{Alexander1992,
abstract = {In traditional explanations of planning, a dichotomy is assumed between the public sector and the free market, and planning is associated with government intervention. An alternative account of planning in both the public and private sectors is offered in the transaction cost theory of planning. Extending economic transaction cost theory into the public and the interorganizational domains suggests that both economic and political markets do not need planning, since planning is associated with nonmarket hierarchical forms of organization and organizational systems. The transaction cost theory of planning accounts for planning in the public and private sectors alike and offers a link between planning, coordination, and implementation. Perhaps it also raises questions that may stimulate exploration of the relation between organizational and interorganizational structures and planning processes.},
author = {Alexander, Ernest R},
doi = {10.1080/01944369208975793},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Alexander - 1992 - A Transaction Cost Theory of Planning.pdf:pdf},
issn = {0194-4363},
journal = {Journal of the American Planning Association},
keywords = {design theory,reslience},
mendeley-tags = {design theory,reslience},
number = {2},
pages = {190--200},
title = {{A Transaction Cost Theory of Planning}},
url = {http://pqasb.pqarchiver.com/planning/access/134997.html?dids=134997:134997:134997\&FMT=ABS\&FMTS=ABS:FT:PAGE\&date=Spring+1992\&author=Alexander,+Ernest+R.\&pub=American+Planning+Association.+Journal+of+the+American+Planning+Association\&edition=\&startpage=190\&},
volume = {58},
year = {1992}
}
@article{Herrmann,
author = {Herrmann, Jeffrey W and Schmidt, Linda C},
file = {:D$\backslash$:/Mendeley/Herrmann, Schmidt - Unknown - Product Development and Decision Production Systems.pdf:pdf},
pages = {1--28},
title = {{Product Development and Decision Production Systems}}
}
@article{Walker2006,
abstract = {This paper is a work-in-progress account of ideas and propositions about resilience in social-ecological systems. It articulates our understanding of how these complex systems change and what determines their ability to absorb disturbances in either their ecological or their social domains. We call them "propositions" because, although they are useful in helping us understand and compare different social-ecological systems, they are not sufficiently well defined to be considered formal hypotheses. These propositions were developed in two workshops, in 2003 and 2004, in which participants compared the dynamics of 15 case studies in a wide range of regions around the world. The propositions raise many questions, and we present a list of some that could help define the next phase of resilience-related research.},
author = {Walker, Brian and Gunderson, Lance and Kinzig, Ann and Folke, Carl and Carpenter, Steve and Schultz, Lisen},
doi = {13},
file = {:D$\backslash$:/Mendeley/30.pdf:pdf},
isbn = {1708-3087},
issn = {17083087},
journal = {Ecology and Society},
keywords = {Adaptatability,Change,Propositions,Resilience,Social-ecological systems,Synthesis,Theory,Transformability},
number = {1},
title = {{A handful of heuristics and some propositions for understanding resilience in social-ecological systems}},
volume = {11},
year = {2006}
}
@article{Wu2003,
author = {Wu, Hsien-Chung},
doi = {10.1016/S0377-2217(02)00140-6},
file = {:D$\backslash$:/Mendeley/Wu - 2003 - The fuzzy estimators of fuzzy parameters based on fuzzy random variables.pdf:pdf},
issn = {03772217},
journal = {European Journal of Operational Research},
keywords = {bayes,estimator,fuzzy,fuzzy random variable,fuzzy real number,fuzzy sets,nonlinear programming},
number = {1},
pages = {101--114},
title = {{The fuzzy estimators of fuzzy parameters based on fuzzy random variables}},
volume = {146},
year = {2003}
}
@article{Wears2010,
abstract = {Resilience is a way of behaving seen in complex work systems, whereby they are able to largely meet their fundamental goals despite threats and challenges to their work and even their existence. It is not something a system has, but rather something a system does, or even more specifically, the way in which a system does what it does. Because resilient behaviour (or lack thereof) is manifested over time, the dynamics of resilience are of interest. Studies of resilience to date have been largely descriptive, but understanding of how resilient performance comes about, and especially how we might enhance it, or recognize that a system is losing it, has been difficult. This work uses system dynamics models to develop inductively a theory of activities resulting in resilient performance in complex systems, and to elaborate on previous representations of system resilience. Such models might be useful in two ways: explaining how resilient behaviours observed might come about; and exploring the temporal dynamics of changes in state (for example, suggesting leading rather than lagging indicators of performance).},
author = {Wears, R. L.},
doi = {10.1177/154193121005400426},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Wears - 2010 - Exploring the Dynamics of Resilience.pdf:pdf},
isbn = {9781617820885},
issn = {1071-1813},
journal = {Proceedings of the Human Factors and Ergonomics Society Annual Meeting},
keywords = {resilience},
mendeley-tags = {resilience},
number = {4},
pages = {394--398},
title = {{Exploring the Dynamics of Resilience}},
volume = {54},
year = {2010}
}
@book{Aubin2014,
author = {Aubin, Jean-Pierre},
booktitle = {Journal of Happiness Studies},
file = {:D$\backslash$:/Mendeley/Aubin - 2014 - Time and Money.pdf:pdf},
isbn = {978-0-415-07982-2},
issn = {13894978},
publisher = {Springer International Publishing},
title = {{Time and Money}},
url = {http://resolver.scholarsportal.info/resolve/13894978/v10i0002/113\_tam.xml},
year = {2014}
}
@article{Straeter2006,
abstract = {The European Air Traffic Management system undergoes a dramatic adoption is the next couple of years. Until the year 2020 doubling of traffic, increased automation and increased autonomous operation of aircrafts, and considerable changes of the airspace structure is to be expected. In order to provide a still a safe system in this situation, several concerted activities are initiated which are bound into the ESARR framework (ESARR means European Safety Regulatory Requirements). As part of the ESARR framework, quantitative safety assessment of a planned system change needs to be conducted, which addresses technological, procedural and human contributions to safety performance. However, the power of quantitative risk assessment is depending on the power of the risk assessment methods used. Regarding Human reliability often old fashioned method are used which predetermine misleading safety improvements as they result from a systematical mis-assessment of the human contribution to risk and safety. The resilience principles are used to define a better approach to Human Reliability Assessment (HRA). Note that the paper does not propose to merge Human Reliability and Resilience but to apply the resilience principles to inclusion of Human Reliability Assessment into safety assessments.},
author = {Straeter, O},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Straeter - 2006 - The dilemma of ill-defining the safety performance of systems if using a non-resilient safety assessment approach.pdf:pdf},
journal = {\ldots Safety R\&D \ldots},
keywords = {resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
pages = {1--14},
title = {{The dilemma of ill-defining the safety performance of systems if using a non-resilient safety assessment approach}},
url = {http://www.resilience-engineering-asso.org/ACTES/2006/StraeterEtAl.pdf},
year = {2006}
}
@article{Piaszczyk2011a,
abstract = {This paper presents a methodology for Model Based Systems Engineering (MBSE) utilizing the guidelines provided by the Department of Defense Architectural Framework (DoDAF). MBSE focuses the system engineering process on system modeling. Thus, requirements derivation, system design, integration, verification, and validation activities all center around the model of the system. System models can be built in many ways. This paper presents an approach using DoDAF. Visual accessibility of the DoDAF views facilitates full participation by all system stakeholders, including the customers, developers, and implementers, and enables the necessary dialogue. The approach promotes communications among the members of the development team and speeds up the iterations of the systems engineering process. The paper illustrates the utility of the DoDAF artifacts by means of a simplified but comprehensive, easy to follow, illustrative example.},
author = {Piaszczyk, C},
doi = {10.1002/sys},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Piaszczyk - 2011 - Model Based Systems Engineering with Department of Defense Architectural Framework.pdf:pdf},
issn = {1098-1241, 1098-1241},
journal = {Systems Engineering},
keywords = {52: Numerical Analysis,63: Mathematics and Computation (CE),63: Mathematics and Computation (MT),Mechanical \& Transportation Engineering Abstracts,Simulation,and Modeling (,resilience,systems engineering},
mendeley-tags = {resilience,systems engineering},
number = {3},
pages = {305--326},
title = {{Model Based Systems Engineering with Department of Defense Architectural Framework}},
url = {http://ezproxy.lib.ucf.edu/login?url=http://search.proquest.com/docview/926281441?accountid=10003$\backslash$nhttp://sfx.fcla.edu/ucf?url\_ver=Z39.88-2004\&rft\_val\_fmt=info:ofi/fmt:kev:mtx:journal\&genre=article\&sid=ProQ:ProQ:civilengineering\&atitle=Model+Based+Systems},
volume = {14},
year = {2011}
}
@article{Das1996,
abstract = {All mechanical designs pass through a series of formal and informal redesign steps, involving the analysis of functionality, manufacturability, cost and other life-cycle factors. The speed and efficacy of these steps has a major influence on the lead time of the product from conceptualization to launching. In this paper we propose a methodology for automatically generating redesign suggestions for reducing setup costs for machined parts. Given an interpretation of the design as a collection of machinable features, our approach is to generate alternate machining features by making geometric changes to the original features, and add them to the feature set of the original part to create an extended feature set. The designer may provide restrictions on the design indicating the type and extent of modifications allowed on certain faces and volumes, in which case all redesign suggestions generated by our approach honour those restrictions. By taking combinations of features from the extended feature set generated above, we can generate modified versions of the original design that still satisfy the designer's intent. By considering precedence constraints, we can estimate the setup time that will be required for each design. Any modified design whose setup time is less than that of the original design can be presented to the designer as a possible way to modify the original design. Copyright ?? 1996 Elsevier Science Ltd.},
author = {Das, Diganta and Gupta, Satyandra K. and Nau, Dana S.},
doi = {10.1016/0010-4485(95)00034-8},
file = {:D$\backslash$:/Mendeley/Nau - 1996 - GENERATING REDESIGN SUGGESTIONS TO REDUCE SETUP COST 1 Introduction 2 Related Work.pdf:pdf},
issn = {00104485},
journal = {CAD Computer Aided Design},
number = {10},
pages = {763--782},
title = {{Generating redesign suggestions to reduce setup cost: A step towards automated redesign}},
volume = {28},
year = {1996}
}
@article{Furniss2011,
abstract = {Processes that enable an effective response to unexpected events and vulnerabilities that lie outside the scope of formal procedures can be described as being resilient. There are many such descriptions of resilience within and across different domains. Comparison and generalisation is difficult because resilience is not a component of a system and should be understood as an emergent property. Here we provide a framework for reasoning about resilience that requires representation of the level of analysis (from the individual to operational), a traceable link from abstract theory to specific observations, resilience mechanisms, and contextual factors. This moves forward an agenda to systematically observe concrete manifestations of resilience within and across domains. We illustrate the application of the framework by considering a case study of the performance of nuclear power plant (NPP) operators in an experimental scenario. This paper focuses on the small team level of analysis. The framework presented here provides the basis for developing concrete measures for improving the resilience of organisations through training, system design, and organisational learning. ?? 2010 Elsevier Ltd.},
author = {Furniss, Dominic and Back, Jonathan and Blandford, Ann and Hildebrandt, Michael and Broberg, Helena},
doi = {10.1016/j.ress.2010.06.025},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Furniss et al. - 2011 - A resilience markers framework for small teams.pdf:pdf},
isbn = {0951-8320},
issn = {09518320},
journal = {Reliability Engineering and System Safety},
keywords = {Markers,Nuclear power,Resilience engineering,Small teams,framework,resilience},
mendeley-tags = {framework,resilience},
number = {1},
pages = {2--10},
title = {{A resilience markers framework for small teams}},
volume = {96},
year = {2011}
}
@article{Popescu2014,
author = {Popescu, Mihai Radu},
file = {:D$\backslash$:/Mendeley/Popescu - 2014 - Speeding Through Haskell.pdf:pdf},
title = {{Speeding Through Haskell}},
year = {2014}
}
@book{Sandbor2013,
address = {Singapore},
author = {Sandbor},
isbn = {978-981-4383-34-9},
pages = {1--421},
publisher = {World Scientific Publishing Co. Pte. Ltd.},
title = {{Cost Analysis of Electronic Systems}},
year = {2013}
}
@article{Baroud2014,
abstract = {This work demonstrates a time-dependent paradigm for resilience and associated stochastic metrics in a waterway transportation context. We deploy two stochastic resilience-based component importance measures that highlight the critical waterway links that contribute to waterway network resilience and develop an optimization approach that determines the order in which disrupted links should be recovered for improved resilience. A data-driven case study illustrates these metrics to describe commodity flows along the various links of the US Mississippi River Navigation System. © 2013 Elsevier Ltd.},
author = {Baroud, Hiba and Barker, Kash and Ramirez-Marquez, Jose E. and {Rocco S.}, Claudio M.},
doi = {10.1016/j.tre.2013.11.010},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Baroud et al. - 2014 - Importance measures for inland waterway network resilience.pdf:pdf},
issn = {13665545},
journal = {Transportation Research Part E: Logistics and Transportation Review},
keywords = {Importance measures,Inland waterways,Network resilience},
pages = {55--67},
publisher = {Elsevier Ltd},
title = {{Importance measures for inland waterway network resilience}},
url = {http://dx.doi.org/10.1016/j.tre.2013.11.010},
volume = {62},
year = {2014}
}
@article{Equation1958,
author = {Equation, I T H E Balance},
file = {:D$\backslash$:/Mendeley/Use - 1964 - MONTHLY WEATHER.pdf:pdf},
journal = {Weather},
number = {1},
pages = {329--332},
title = {{Monthly Weather}},
volume = {92},
year = {1958}
}
@article{Patterson2015,
author = {Patterson, Mary D and Wears, Robert L},
doi = {10.1016/j.ress.2015.03.014},
file = {:D$\backslash$:/Mendeley/1-s2.0-S0951832015000800-main.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
keywords = {Resilience},
mendeley-tags = {Resilience},
pages = {1--9},
title = {{Resilience and precarious success}},
url = {http://linkinghub.elsevier.com/retrieve/pii/S0951832015000800},
year = {2015}
}
@article{Shaniavski2004,
author = {Shaniavski, Aa and Artamonov, Ma},
doi = {10.1023/B:FRAC.0000040994.96074.bf},
file = {:D$\backslash$:/Mendeley/Shaniavski, Artamonov - 2004 - Fractal dimensions for fatigue fracture surfaces performed on micro- and meso-scale levels.pdf:pdf},
issn = {0376-9429},
journal = {International journal of fracture},
number = {1983},
pages = {309--314},
title = {{Fractal dimensions for fatigue fracture surfaces performed on micro-and meso-scale levels}},
url = {http://link.springer.com/article/10.1023/B:FRAC.0000040994.96074.bf},
year = {2004}
}
@article{Introduction2014,
author = {Introduction, Guest Editorial and Issue, Special and Power, Wind},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Introduction, Issue, Power - 2014 - Guest Editorial Introduction to the Special Issue on Wind Power.pdf:pdf},
number = {1},
pages = {1--3},
title = {{Guest Editorial Introduction to the Special Issue on Wind Power}},
volume = {22},
year = {2014}
}
@article{Herrmann2011,
author = {Herrmann, Jeffrey W},
file = {:D$\backslash$:/Mendeley/Herrmann - 2011 - Engineering Decision Making and Risk Management.pdf:pdf},
isbn = {978-0-8247-0808-5},
journal = {Manager},
title = {{Engineering Decision Making and Risk Management}},
year = {2011}
}
@article{Lundberg2006,
abstract = {The concept of ‘resilience’ is often absent in accident investigations, most likely because one of the central notions in resilience, ‘requisite imagination’, seems to be of limited utility when used in hindsight. In this paper we argue that requisite imagination is often a mirage, and that its false promise may well be based on treating stability and resilience as one unified concept. It is important to see the distinction between recommendations from accident investigations that aim at maintaining the ability to respond to known disturbances, (stability) and recommendations aimed at increasing the ability to cope with irregular and unexampled events (resilience). Instead of attempting to maximize resilience and stability at the same time, it may be more fruitful to try to balance these properties of a system. Thus, in accident investigation a safety perspective should include both traditional stabilityenhancing perspectives as well as a resilience perspective},
author = {Lundberg, Jonas and Johansson, Bj\"{o}rn},
file = {:D$\backslash$:/Mendeley/Lundberg\_Johansson.pdf:pdf},
journal = {2nd Resilience Engineering International Symposium},
title = {{Resilience , Stability and Requisite Interpretation in Accident Investigations}},
url = {https://docs.google.com/a/wmu.se/file/d/0B2lfx\_f4ofuXdGhvMUtNNHpZMjA/edit?usp=sharing},
year = {2006}
}
@book{Ross2005,
abstract = {Revised and updated second edition with new material Text for a transition course between calculus and more advanced analysis courses Contains new material on topics such as irrationality of pi, the Baire category theorem, Newton's method and the secant method, and continuous nowhere-differentiable functions Includes new examples and improved proofs For over three decades, this best-selling classic has been used by thousands of students in the United States and abroad as a must-have textbook for a transitional course from calculus to analysis. It has proven to be very useful for mathematics majors who have no previous experience with rigorous proofs. Its friendly style unlocks the mystery of writing proofs, while carefully examining the theoretical basis for calculus. Proofs are given in full, and the large number of well-chosen examples and exercises range from routine to challenging. The second edition preserves the book’s clear and concise style, illuminating discussions, and simple, well-motivated proofs. New topics include material on the irrationality of pi, the Baire category theorem, Newton's method and the secant method, and continuous nowhere-differentiable functions. Review from the first edition: "This book is intended for the student who has a good, but na\"{\i}ve, understanding of elementary calculus and now wishes to gain a thorough understanding of a few basic concepts in analysis.... The author has tried to write in an informal but precise style, stressing motivation and methods of proof, and ... has succeeded admirably." —MATHEMATICAL REVIEWS},
author = {Ross, Kenneth A},
booktitle = {Materials Today},
doi = {10.1016/S1369-7021(05)71128-7},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Ross - 2005 - Elementary analysis.pdf:pdf},
isbn = {978-1-4614-6270-5},
issn = {13697021},
number = {10},
pages = {47--47},
title = {{Elementary analysis}},
volume = {8},
year = {2005}
}
@article{Levitin1998,
abstract = {This paper generalizes a redundancy optimization problem to
multi-state systems, where the system and its components have a range of
performance levels-from perfect functioning to complete failure. The
components are: (1) chosen from a list of products available in the
market; and (2) characterized by their nominal performance level,
availability and cost. System availability is represented by a
multi-state availability function, which extends the binary-state
availability. To satisfy the required multi-state system availability,
the redundancy for each component can be used. A procedure which
determines the minimal-cost series-parallel system structure subject to
a multi-state availability constraint is proposed. A fast procedure is
developed, based on a universal generating function, to evaluate the
multi-state system availability. Two important types of systems are
considered and special operators for the universal generating function
determination are introduced. A genetic algorithm is used as an
optimization technique. Examples are given},
author = {Levitin, Gregory and Lisnianski, Anatoly and Ben-Haim, Hanoch and Elmakis, David},
doi = {10.1109/24.722283},
file = {:D$\backslash$:/Mendeley/Levitin et al. - 1998 - Redundancy optimization for series-parallel multi-state systems.pdf:pdf},
issn = {00189529},
journal = {IEEE Transactions on Reliability},
keywords = {Genetic algorithm,Multi-state availability,Performance level,Redundancy optimization,Universal generating function},
number = {2},
pages = {165--172},
title = {{Redundancy optimization for series-parallel multi-state systems}},
volume = {47},
year = {1998}
}
@article{Lopes2005,
author = {Lopes, Fernando H and Silva, D a},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Lopes, Silva - 2005 - Pr E oo f Pr E oo f.pdf:pdf},
keywords = {brain modeling,computational neuroscience,ner-,simulation,vous system},
pages = {1--3},
title = {{Pr E oo f Pr E oo f}},
year = {2005}
}
@article{Potters2005,
abstract = {This contribution to the proceedings of the Cracow meeting on `Applications of Random Matrix Theory' summarizes a series of studies, some old and others more recent on financial applications of Random Matrix Theory (RMT). We first review some early results in that field, with particular emphasis on the applications of correlation cleaning to portfolio optimisation, and discuss the extension of the Marcenko-Pastur (MP) distribution to a non trivial `true' underlying correlation matrix. We then present new results concerning different problems that arise in a financial context: (a) the generalisation of the MP result to the case of an empirical correlation matrix (ECM) constructed using exponential moving averages, for which we give a new elegant derivation (b) the specific dynamics of the `market' eigenvalue and its associated eigenvector, which defines an interesting Ornstein-Uhlenbeck process on the unit sphere and (c) the problem of the dependence of ECM's on the observation frequency of the returns and its interpretation in terms of lagged cross-influences.},
archivePrefix = {arXiv},
arxivId = {physics/0507111},
author = {Potters, Marc and Bouchaud, Jean Philippe and Laloux, Laurent},
eprint = {0507111},
file = {:D$\backslash$:/Mendeley/Potters, Bouchaud, Laloux - 2005 - Financial Applications of Random Matrix Theory Old Laces and New Pieces.pdf:pdf},
issn = {05874254},
journal = {Acta Physica Polonica B},
number = {9},
pages = {2767--2784},
pmid = {232226500014},
primaryClass = {physics},
title = {{Financial applications of random matrix theory: Old laces and new pieces}},
volume = {36},
year = {2005}
}
@article{Vidal2009,
abstract = {This article aims to describe the characteristics of collective working situations in complex systems - especially those in nuclear power plants - related to common forms of cooperation, in order to improve systems resilience. In addition, we will try to detail some aspects of collective working situations, emphasizing the differences between various forms of control. The similarities between work activities (multi-addressed messages, linkage to regulation, central and peripheral information) are nonetheless exposed. We conclude by proposing a contribution to support systems design, thus facilitating cooperation in teamwork activities. ?? 2009 Elsevier Ltd. All rights reserved.},
author = {Vidal, Mario C R and Carvalho, Paulo V R and Santos, Marcello S. and Santos, Isaac J L Dos},
doi = {10.1016/j.jlp.2009.04.005},
file = {:D$\backslash$:/Mendeley/Carvalho - Collective work and resilience of complex systems.pdf:pdf},
isbn = {0950-4230},
issn = {09504230},
journal = {Journal of Loss Prevention in the Process Industries},
keywords = {Collective work,Complex systems control,Resilience,Safety},
number = {4},
pages = {516--527},
publisher = {Elsevier Ltd},
title = {{Collective work and resilience of complex systems}},
url = {http://dx.doi.org/10.1016/j.jlp.2009.04.005},
volume = {22},
year = {2009}
}
@article{Ayyub2014b,
author = {Ayyub, Bilal M},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Ayyub - 2014 - The United Nations Office for Disaster Risk Reduction.pdf:pdf},
title = {{The United Nations Office for Disaster Risk Reduction}},
url = {http://www.unisdr.org/we/inform/terminology\#letter-d},
year = {2014}
}
@article{Murray2013,
author = {Murray, Richard M and Day, John C and Ingham, Michel D and Reder, Leonard J and Williams, Brian C},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Murray et al. - 2013 - Engineering Resilient Space Systems.pdf:pdf},
number = {February},
title = {{Engineering Resilient Space Systems}},
year = {2013}
}
@article{Dominkovics2008,
abstract = {In this paper, the usability of fractal description of dendrites in failure analysis is discussed. Dendrites grow during electrochemical migration (ECM) causing failures in the form of short circuits between conductive wirings and leads in microcircuit interconnection and packaging elements, especially on printed wiring boards (PWBs). The parameters of the dendrite growth process are influenced by functional (electrical) and environmental conditions as well as by the material composition of metallization stripes and surface finishes. Mathematically, dendrites can be described as fractals and therefore they can be characterized with fractal dimension values calculated by various computerized pattern processing methods. We have found relationship between chemical composition of surface finishes and fractal dimensions of dendrites grown from them. This hypothesis has been proved in three steps: first, dendrites were grown by simple water drop test (WDT) series in order to get good quality, reproducible test specimens; in the second step, optical photomicrographs were taken from the dendrite structures and finally these micrographs were analyzed using computerized algorithms. The result is that fractal dimensions are material specific and so they can be used to describe the material composition. This is not only an important theoretical result in understanding dendrite growth mechanisms, but it also has a useful practical aspect: short detection and optical inspection can be combined with simple calculations to identify materials involved into electrochemical migration failures without making more complicated elemental chemical analysis. © 2008 Elsevier Ltd. All rights reserved.},
author = {Dominkovics, Csaba and Har\'{s}nyi, G\'{a}bor},
doi = {10.3311/pp.ee.2008-1-2.02},
file = {:D$\backslash$:/Mendeley/Dominkovics, Harsanyi - 2008 - Fractal description of dendrite growth during electrochemical migration.pdf:pdf},
isbn = {1424412188},
issn = {03246000},
journal = {Periodica Polytechnica, Electrical Engineering},
keywords = {Applied fractal theory,Electrochemical migration,Water drop test},
number = {1-2},
pages = {13--19},
title = {{Fractal description of dendrite growth during electrochemical migration}},
volume = {52},
year = {2008}
}
@article{Zellmer2009,
abstract = {Ecosystem restoration is fast becoming the third major strategy of the modern environmental era, which began in the 1960s by seeking to mitigate the effects of conventional, exploitation-dominated resource management and then, in the 1970s, turned to pollution prevention and preservation of wildlife, recreational opportunities, and other multiple uses.1 The goals of recent restoration plans are anything but simple. Those who seek to restore any ecosystem must deal with two separate problems. The first is a social problem, which is an attempt to define goals and objectives, or to develop a collective sense of what society wants. Closely tied to that articulation of "what we want" is the complex array of pre-existing and emerging social structures- laws, policies, and institutions that frame the options for achieving a vision of restoration. The second problem is scientific, in which experts attempt to lay out a range of ecological trajectories, structures (such as biological diversity), and functions that define possible restoration outcomes. Almost invariably, the first problem (what do we want?) overshadows the second problem (what can we get?) in implementation. As a result, both goals become difficult if not impossible to attain and, over time, both ecological and social restoration aspirations fail. A key challenge for designers and managers of restoration plans is to recognize the interplay between, and constraints imposed by, both the sociopolitical and biophysical worlds. By weaving ecological principles and legal analysis together, we hope to shed light on the successes and failures of two landmark restoration projects: the Grand Canyon of the Colorado River and the Florida Everglades. These projects share common goals-to restore degraded habitat and to maintain water supplies. They also share a common problem-making meaningful progress towards restoration goals. In the Grand Canyon, modest successes have been achieved through an adaptive management program that attempts to blend the social and ecological objectives. In the Everglades, however, the restoration approach has separated the ecological from the social, legal, and political domains, and as a result has accomplished very little.2 The successes and failures of these experiments in ecosystem restoration are a result of many factors. In this Article, we focus on three elemental ingredients. The first is the emerging system property of resilience, a concept that describes a more complex model of change and restoration than typical resource management goals related to maximizing social uses and achieving optimum yields of resource outputs. Resilience is a characteristic of both social and ecological systems. Resilience theory suggests that complex systems can exist in fundamentally different regimes, and resilience is the property that mediates transitions among those regimes. Hence resilience must be overcome when undertaking objectives that involve regime changes, such as an ecological restoration or a social transformation. In fact, a comparative analysis of the Grand Canyon and Everglades projects reveals that resilience may not always be a good thing, particularly when it exhibits itself as entrenched stakeholder interests or institutions that do not embrace change. A second significant factor in achieving restoration goals is legislation and other legal requirements, which can either enable or constrain ecosystem restoration. The Grand Canyon Protection Act of 19923 and the Everglades restoration provisions of the Water Resources Development Act of 20004 specifically authorize restoration. At the same time, existing, generally applicable legislation, such as the Clean Water Act5 and the Endangered Species Act,6 remains in play and adds to the complexities of ecosystem restoration. The third factor involves the administration of legislation through agencies' initiatives and public participation, particularly stakeholder involvement. Whether combative, collaborative, or somewhere in between, the participants' commitment to experimentation and adaptation in the implementation of a restoration plan has a profound influence on the speed and trajectory of restoration. The remainder of this Article is structured as follows. Part II discusses the concept of resilience and how it underpins notions of restoration and sustainability. National legislative goals and requirements related to these concepts are then described. Next, Part III takes a close look at the physical characteristics and specific legislative directives for the Everglades and the Grand Canyon. Part IV sets forth several "lessons learned" from these two restoration projects. Finally, Part V concludes with broader observations about restoration and resilience. Success is not possible, and failure may be inevitable, unless the science of ecology, environmental law, and public administration are calibrated to foster experimentation, learning, and adaptation in management strategies.},
author = {Zellmer, Sandi and Gunderson, Lance},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Zellmer, Gunderson - 2009 - Why resilience may not always be a good thing Lessons in ecosystem restoration from Glen Canyon and the Ever.pdf:pdf},
journal = {Nebraska Law Review},
keywords = {design theory,resilience,reslience},
mendeley-tags = {design theory,resilience,reslience},
number = {4},
pages = {893--949},
title = {{Why resilience may not always be a good thing: Lessons in ecosystem restoration from Glen Canyon and the Everglades}},
url = {http://digitalcommons.unl.edu/nlr/vol87/iss4/2},
volume = {87},
year = {2009}
}
@article{Huang2011,
abstract = {BACKGROUND: The vitamin D receptor (VDR) polymorphisms have been reported to be associated with multiple sclerosis (MS), however, evidence remains conflicting. A meta-analysis was conducted to investigate this association. METHODS: We searched Pubmed, Medline and Embase databases for case-control studies evaluating the association between the VDR Apa-I, Bsm-I, Fok-I, Taq-I polymorphisms and MS risk. Data were extracted using standardized forms and odds ratios (OR) with 95\% confidence intervals (CI) were calculated. RESULTS: 11 case-control studies involving a total of 2599 cases and 2816 controls were included in this meta-analysis. Available data did not suggest an association between any of the VDR polymorphisms and the risk for MS. For Taq-I, which is the most investigated VDR polymorphism with 8 studies (2472 cases and 2446 controls), the combined OR was 1.12 (95\% CI: 1.00-1.26) for the dominant model (tt+Tt vs. TT), 1.03(95\% CI: 0.88-1.20) for the recessive model (tt vs. Tt+TT), and 1.04 (95\% CI: 0.78-1.38) for the homozygote model (tt vs. TT). ORs for other VDR polymorphisms were similar. CONCLUSION: The VDR Apa-I, Bsm-I, Fok-I and Taq-I polymorphisms are not associated with MS risk.},
author = {Huang, Jian and Xie, Zheng-Fu},
doi = {10.1016/j.jns.2011.09.024},
file = {:D$\backslash$:/Mendeley/Huang, Xie - 2011 - Polymorphisms in the vitamin D receptor gene and multiple sclerosis risk A meta-analysis of case-control studies.pdf:pdf},
issn = {1878-5883},
journal = {Journal of the neurological sciences},
number = {3},
pages = {311--326},
pmid = {22029942},
title = {{Polymorphisms in the vitamin D receptor gene and multiple sclerosis risk: A meta-analysis of case-control studies.}},
url = {http://www.ncbi.nlm.nih.gov/pubmed/22031508},
volume = {14},
year = {2011}
}
@article{Janssen2006,
abstract = {This paper presents the results of a bibliometric analysis of the knowledge domains resilience, vulnerability and adaptation within the research activities on human dimensions of global environmental change. We analyzed how 2286 publications between 1967 and 2005 are related in terms of co-authorship relations, and citation relations. The number of publications in the three knowledge domains increased rapidly between 1995 and 2005. However, the resilience knowledge domain is only weakly connected with the other two domains in terms of co-authorships and citations. The resilience knowledge domain has a background in ecology and mathematics with a focus on theoretical models, while the vulnerability and adaptation knowledge domains have a background in geography and natural hazards research with a focus on case studies and climate change research. There is an increasing number of cross citations and papers classified in multiple knowledge domains. This seems to indicate an increasing integration of the different knowledge domains. © 2006 Elsevier Ltd. All rights reserved.},
author = {Janssen, Marco a. and Schoon, Michael L. and Ke, Weimao and B\"{o}rner, Katy},
doi = {10.1016/j.gloenvcha.2006.04.001},
file = {:D$\backslash$:/Mendeley/gec2006networks.pdf:pdf},
isbn = {0959-3780},
issn = {09593780},
journal = {Global Environmental Change},
keywords = {Adaptation,Citations,Co-authorship networks,Knowledge domains,Publications,Resilience,Vulnerability},
number = {3},
pages = {240--252},
title = {{Scholarly networks on resilience, vulnerability and adaptation within the human dimensions of global environmental change}},
volume = {16},
year = {2006}
}
@article{Juarrero2010,
author = {Juarrero, Alicia},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Juarrero - 2010 - Complex Dynamical Systems Theory.pdf:pdf},
journal = {Cognitive Edge},
pages = {1--11},
title = {{Complex Dynamical Systems Theory}},
year = {2010}
}
@article{Øien2011,
abstract = {Development of early warning indicators to prevent major accidents - to 'build safety' - should rest on a sound theoretical foundation, including basic concepts, main perspectives and past developments, as well as an overview of the present status and ongoing research. In this paper we have established the theoretical basis for development of indicators used as early warnings of major accidents. Extensive work on indicators have been carried out in the past, and this could and should have been better utilized by industry, e.g., by focusing more on major hazard indicators, and less on personal safety indicators. Recent discussions about safety indicators have focused on the distinction between leading and lagging indicators; however, a discussion on terms should not impede the development of useful indicators that can provide (early) warnings about potential major accidents. © 2010 Elsevier Ltd.},
author = {\O ien, K. and Utne, I. B. and Herrera, I. a.},
doi = {10.1016/j.ssci.2010.05.012},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/\O ien, Utne, Herrera - 2011 - Building Safety indicators Part 1 - Theoretical foundation.pdf:pdf},
isbn = {09257535},
issn = {09257535},
journal = {Safety Science},
keywords = {Indicators,Risk,Risk management,Safety,measurement,resilience},
mendeley-tags = {measurement,resilience},
number = {2},
pages = {148--161},
title = {{Building Safety indicators: Part 1 - Theoretical foundation}},
volume = {49},
year = {2011}
}
@inproceedings{Chang2015,
abstract = {In current practice, economic analysis of disaster risk reduction often neglects time-dependent losses such as business interruption and income losses that accrue over time during post-disaster recovery. This paper argues that incorporating time-dependent losses is critical to making investment decisions that foster disaster resilience. Drawing from the previous empirical and modeling work, the paper argues that incorporating economic impacts of short-term service outage and restoration is relatively straightforward and can be reeadily accomplished under certain assumptions -- most notably, assumptions of stable economic structure. Economic recovery is complex and highly context-dependent, however, and will remain very challenging to model, particularly for catastrophic events. To illustrate these points, examples are drawn from several cases in the U.S., Japan, and New Zealand.},
address = {Reston},
author = {Chang, Stehanie},
booktitle = {ASCE First Workshop on Resilience},
editor = {Bilal},
keywords = {economics,recovery,resilience},
mendeley-tags = {economics,recovery,resilience},
pages = {80--88},
title = {{Incorporating Recovery into Economic Analysis}},
year = {2015}
}
@article{Question2009,
author = {Question, Tu and Marrow, Using},
file = {:D$\backslash$:/Mendeley/Question, Marrow - 2009 - ENRE 641 Midterm Exam ­ Solution Spring 2009.pdf:pdf},
pages = {6--8},
title = {{ENRE 641 Midterm Exam ­ Solution Spring 2009}},
volume = {1},
year = {2009}
}
@article{Sandborn2002,
author = {Sandborn, Peter and Singh, Pameet},
file = {:D$\backslash$:/Mendeley/Sandborn, Singh - 2002 - Electronic part Obsolescence Driven Product Redesign Optimization.pdf:pdf},
journal = {Proceedings of the 6th Joint FAA/DoD/NASA \ldots},
pages = {1--13},
title = {{Electronic part obsolescence driven product redesign optimization}},
url = {http://www.enme.umd.edu/ESCML/Papers/AgingAircraft.pdf},
year = {2002}
}
@article{Spiegler2012,
abstract = {There is no consensus on the supply chain management definition of resilience. To aid in evaluating the dynamic behaviour of such systems we need to establish clearly elucidated performance criteria that encapsulate the attributes of resilience. A literature review establishes the latter as readiness, responsiveness and recovery. We also identify robustness as a necessary condition that would complement resilience. We find that the Integral of the Time Absolute Error (ITAE) is an appropriate control engineering measure of resilience when it is applied to inventory levels and shipment rates. We use the ITAE to evaluate an often used benchmark model of make-to-stock supply chains consisting of three decision parameters. We use both linear and nonlinear forms of the model in our evaluation. Our findings suggest that optimum solutions for resilience do not yield a system that is robust to uncertainties in lead-time. Hence supply chains will experience drastic changes in their resilience performance when lead-time changes.},
author = {Spiegler, Virginia L. M. and Naim, Mohamed Mohamed and Wikner, Joakim},
doi = {10.1080/00207543.2012.710764},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Spiegler, Naim, Wikner - 2012 - A control engineering approach to the assessment of supply chain resilience.pdf:pdf},
isbn = {00207543},
issn = {0020-7543},
keywords = {HD28 Management. Industrial Management},
number = {21},
pages = {6162--6187},
title = {{A control engineering approach to the assessment of supply chain resilience}},
url = {http://dx.doi.org/10.1080/00207543.2012.710764},
volume = {50},
year = {2012}
}
@article{Zhang2014,
author = {Zhang, Yan Ming and Huang, Kaizhu and Hou, Xinwen and Liu, Cheng Lin},
doi = {10.1109/TCYB.2014.2300489},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Zhang et al. - 2014 - Learning Locality Preserving Graph from Data.pdf:pdf},
isbn = {2168-2267},
issn = {21682267},
journal = {IEEE Transactions on Cybernetics},
number = {11},
pages = {2088--2098},
title = {{Learning Locality Preserving Graph from Data}},
volume = {44},
year = {2014}
}
@article{VanAken2004,
abstract = {Academic management theory has a serious utilization problem. This article argues that it stands a better chance of being adopted for instrumental use if the theory is based on the paradigm of the “design sciences”, like medicine or engineering. Most academic management research is based on the paradigm of the “explanatory sciences”, like physics. The mission of these sciences is to describe, explain and predict, while the core mission of the design sciences is to develop “tested and grounded technological rules”. The paradigm of the design sciences is applied to management research and I discuss the potential of solving its utility problem by combining both types of research.},
author = {{Van Aken}, Joan E.},
doi = {10.1111/j.1467-6486.2004.00430.x},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Van Aken - 2004 - Management Research Based on the Paradigm of the Design Sciences The Quest for Field-Tested and Grounded Technological.pdf:pdf},
isbn = {1467-8551},
issn = {00222380},
journal = {Journal of Management Studies},
keywords = {design theory,resilience,reslience},
mendeley-tags = {design theory,resilience,reslience},
number = {2},
pages = {219--246},
title = {{Management Research Based on the Paradigm of the Design Sciences: The Quest for Field-Tested and Grounded Technological Rules}},
volume = {41},
year = {2004}
}
@article{Matveev1995,
author = {Matveev, V. V.},
doi = {10.1007/BF02209473},
file = {:D$\backslash$:/Mendeley/Fracture - 1990 - Scientific and technical section.pdf:pdf},
issn = {00392316},
journal = {Strength of Materials},
number = {3},
pages = {105--111},
title = {{Scientific and technical section}},
volume = {27},
year = {1995}
}
@article{Dennis2007,
abstract = {Model uncertainty has the potential to change importantly how monetary policy should be conducted, making it an issue that central banks cannot ignore. In this paper, I use a standard new Keynesian business cycle model to analyze the behavior of a central bank that conducts policy with discretion while fearing that its model is misspecified. I begin by showing how to solve linear-quadratic robust Markov-perfect Stackelberg problems where the leader fears that private agents form expectations using the misspecified model. Next, I exploit the connection between robust control and uncertainty aversion to present and interpret my results in terms of the distorted beliefs held by the central bank, households, and firms. My main results are as follows. First, the central bank's pessimism leads it to forecast future outcomes using an expectations operator that, relative to rational expectations, assigns greater probability to extreme inflation and consumption outcomes. Second, the central bank's skepticism about its model causes it to move forcefully to stabilize inflation following shocks. Finally, even in the absence of misspecification, policy loss can be improved if the central bank implements a robust policy.},
author = {Dennis, Richard},
file = {:D$\backslash$:/Mendeley/Dennis - 2007 - FEDERAL RESERVE BANK OF SAN FRANCISCO Model Uncertainty and Monetary Policy.pdf:pdf},
journal = {Working Paper Series from Federal Reserve Bank of San Francisco},
keywords = {model uncertainty, robustness, uncertainty aversio},
number = {May},
title = {{Model uncertainty and monetary policy}},
volume = {09},
year = {2007}
}
@misc{Potters2005a,
abstract = {This contribution to the proceedings of the Cracow meeting on `Applications of Random Matrix Theory' summarizes a series of studies, some old and others more recent on financial applications of Random Matrix Theory (RMT). We first review some early results in that field, with particular emphasis on the applications of correlation cleaning to portfolio optimisation, and discuss the extension of the Marcenko-Pastur (MP) distribution to a non trivial `true' underlying correlation matrix. We then present new results concerning different problems that arise in a financial context: (a) the generalisation of the MP result to the case of an empirical correlation matrix (ECM) constructed using exponential moving averages, for which we give a new elegant derivation (b) the specific dynamics of the `market' eigenvalue and its associated eigenvector, which defines an interesting Ornstein-Uhlenbeck process on the unit sphere and (c) the problem of the dependence of ECM's on the observation frequency of the returns and its interpretation in terms of lagged cross-influences.},
archivePrefix = {arXiv},
arxivId = {physics/0507111},
author = {Potters, Marc and Bouchaud, Jean Philippe and Laloux, Laurent},
booktitle = {Acta Physica Polonica B},
eprint = {0507111},
file = {:D$\backslash$:/Mendeley/Potters, Bouchaud, Laloux - 2005 - FINANCIAL APPLICATIONS OF RANDOM MATRIX THEORY OLD LACES AND NEW PIECES ∗.pdf:pdf},
issn = {05874254},
number = {9},
pages = {2767--2784},
pmid = {232226500014},
primaryClass = {physics},
title = {{Financial applications of random matrix theory: Old laces and new pieces}},
volume = {36},
year = {2005}
}
@article{Nelson2007,
abstract = {Adaptation is a process of deliberate change in anticipation of or in reaction to external stimuli and stress. The dominant research tradi tion on adaptation to environmental change primarily takes an actor-centered view, focusing on the agency of social actors to respond to specific environmental stimuli and emphasizing the reduction of vulnerabilities. The resilience approach is systems orientated, takes a more dynamic view, and sees adaptive capacity as a core feature of resilient social-ecological systems. The two approaches converge in identifying necessary components of adaptation. We argue that resilience provides a useful framework to analyze adaptation processes and to identify appropriate policy responses. We distinguish between incremental adjustments and transformative action and demonstrate that the sources of resilience for taking adaptive action are common across scales. These are the inherent system characteristics that absorb perturbations without losing function, networks and social capital that allow autonomous action, and resources that promote institutional learning},
author = {Nelson, Donald R. and Adger, W. Neil and Brown, Katrina},
doi = {10.1146/annurev.energy.32.051807.090348},
file = {:D$\backslash$:/Mendeley/AnnualReviewofEnvResources\_32\_395-419\_2007.pdf:pdf},
isbn = {1543-5938},
issn = {1543-5938},
journal = {Annual Review of Environment and Resources},
keywords = {adaptive management,governance,risk,social-ecological systems},
number = {1},
pages = {395--419},
pmid = {27892320},
title = {{Adaptation to Environmental Change: Contributions of a Resilience Framework}},
volume = {32},
year = {2007}
}
@article{Sarmiento2009,
author = {Sarmiento, E. and Gonz\'{a}lez-Rodriguez, J. G. and Uruchurtu, J. and Sarmiento, O. and Menchaca, M.},
doi = {10.1149/1.3046636},
file = {:D$\backslash$:/Mendeley/Sarmiento et al. - 2009 - Fractal Analysis of the Corrosion Inhibition of Carbon Steel in a Bromide Solution by Lithium Chromate.pdf:pdf},
isbn = {9781615672882},
issn = {14523981},
journal = {International Journal of Electrochemical Science},
keywords = {Bromide solution,Fractals,Hurst,Inhibition,Steel},
number = {1},
pages = {144--155},
title = {{Fractal analysis of the corrosion inhibition of carbon steel in a bromide solution by lithium chromate}},
volume = {4},
year = {2009}
}
@article{Øien2011a,
abstract = {Petroleum exploration and production in the Barents Sea is a controversial topic. The Goliat field outside the northern coast of Norway will be the first offshore oil development in this region, with planned production start in 2013-2014. Avoiding major accidents at Goliat is critical; not only to reduce the risks to human lives and the environment, but also to gain political acceptance. Providing early warnings of major accidents for Goliat is one of the main objectives of the research project 'Building Safety'. The objective of this paper is to describe the development of early warnings in the form of indicators. In addition, the paper includes an overview of current status of early warnings of accidents in other major hazard industries; the nuclear power industry, the chemical process industry, and aviation. Experiences from these industries, including lessons learned from recent major accidents, have been used as important input to the development of early warning indicators. © 2010 Elsevier Ltd.},
author = {\O ien, K. and Utne, I. B. and Tinmannsvik, R. K. and Massaiu, S.},
doi = {10.1016/j.ssci.2010.05.015},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/\O ien et al. - 2011 - Building Safety indicators Part 2 - Application, practices and results.pdf:pdf},
isbn = {09257535},
issn = {09257535},
journal = {Safety Science},
keywords = {Indicators,Risk,Risk management,Safety,measurement,resilience},
mendeley-tags = {measurement,resilience},
number = {2},
pages = {162--171},
title = {{Building Safety indicators: Part 2 - Application, practices and results}},
volume = {49},
year = {2011}
}
@article{Cochrane2004,
abstract = {This paper covers a number of pitfalls that could hinder the development of a common methodology for estimating flood damage. Such pitfalls include double counting, ignoring post-disaster liabilities, ignoring non-market losses (e.g. recreation, loss of leisure, damage to historic sites and cultural assets, etc.), ignoring the needs of the end user, and questions as to how indirect/systemic losses might be modeled. With one exception, much of what is discussed in the paper is based on off-the-shelf economics and will not prove to be contentious. Regional economists are likely to have different opinions as to how to best model indirect and systemic loss; it is this that will lead to a lively debate as to how to proceed. Assessments of economic fallout from the World Trade Center attack are used to illustrate some of the problems reported in this paper.},
author = {Cochrane and Hal},
doi = {10.1108/09653560410556500},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Cochrane, Hal - 2004 - Economic loss myth and measurement.pdf:pdf},
isbn = {0965-3562},
issn = {0965-3562},
journal = {Disaster Prevention and Management},
keywords = {damage and why,disasters,economics,estimation,loss,measurement,resilience,the elusive concept of},
mendeley-tags = {economics,measurement,resilience},
number = {4},
pages = {290--296},
title = {{Economic loss: myth and measurement}},
volume = {13},
year = {2004}
}
@article{Zeng2014,
author = {Zeng, Wente and Chow, Mo Yuen},
doi = {10.1109/TCYB.2014.2301434},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Zeng, Chow - 2014 - Resilient Distributed Control in the Presence of Misbehaving Agents in Networked Control Systems.pdf:pdf},
issn = {21682267},
journal = {IEEE Transactions on Cybernetics},
number = {11},
pages = {2038--2049},
title = {{Resilient Distributed Control in the Presence of Misbehaving Agents in Networked Control Systems}},
volume = {44},
year = {2014}
}
@article{Lecoze2006,
abstract = {The label resilience has been used in the field of child psychology and of child development to identify the way in which children could cope with adverse events of their past, in order to live (to develop) “normal” lives. In this field, the following definition is in use: "children resilience is a universal capacity which allows a person, group or community to prevent, minimize or overcome the damaging effects of adversity." (Grotberg, 1997). It is interesting to note that the concepts as discussed in the collective book on resilience engineering (Hollnagel, Woods \& Leveson, 20061) share some similarities with the methodological and theoretical developments found in the child resilience field. Three examples of these similarities are discussed here. First we discuss the cross disciplinary nature of the child and organisational resilience. Secondly, we discuss the similarities between the risk factors versus resilience factors in both fields. And finally, we introduce the importance of the cognitive and social construction of safety.},
author = {Lecoze, Jean-christophe and Capo, Sophie},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Lecoze, Capo - 2006 - A Conceptual and Methodological Comparison with the Field of Child Resilience.pdf:pdf},
journal = {2nd Symposium on Resilience Engineering Juan-les-Pins, France 8-10Nov},
keywords = {comparative,resilience},
mendeley-tags = {comparative,resilience},
title = {{A Conceptual and Methodological Comparison with the Field of Child Resilience}},
url = {http://www.resilience-engineering.org/proceedingsRE2\_5.htm},
year = {2006}
}
@article{Enre,
author = {Enre, Emanuel},
file = {:D$\backslash$:/Mendeley/Enre - Unknown - C that survives to 3528 hours appears to be an outlier when compared to the rest of the units at 200.pdf:pdf},
pages = {3--5},
title = {{C that survives to 3528 hours appears to be an outlier when compared to the rest of the units at 200}}
}
@misc{Samee2009,
author = {Samee, a. and Li, Z. H. and Zhang, C. H. and Huang, Z. P.},
booktitle = {Information Technology Journal},
doi = {10.3923/itj.2009.855.862},
file = {:D$\backslash$:/Mendeley/Samee et al. - 2009 - Fractal cluster based aging model of electrical treeing in polymeric insulation.pdf:pdf},
issn = {18125638},
keywords = {Electrical treeing, micro voids,Multi-stress aging,Thermally-activated electrically-enhanced bond bre},
number = {6},
pages = {855--862},
title = {{Fractal cluster based aging model of electrical treeing in polymeric insulation}},
volume = {8},
year = {2009}
}
@article{Purpose2014,
author = {Purpose, The},
file = {:D$\backslash$:/Mendeley/Purpose - 2014 - The Julia Express.pdf:pdf},
pages = {1--13},
title = {{The Julia Express}},
year = {2014}
}
@article{Hoffman2009,
abstract = {This essays examined some human-centering issues for the Networld, placed primarily for convenience into five categories: antitrust in technology, a concensus on what "trust" is, interpersonal trust versus trust in automation, trusting as a dynamic process, and resilience engineering for the active management of trust. The approach of designing and foundation for the active management of trust in cyberdomains.},
author = {Hoffman, R.R. and Lee, J.D. and Woods, D.D. and Shadbolt, N. and Miller, J. and Bradshaw, J.M.},
doi = {10.1109/MIS.2009.124},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Hoffman et al. - 2009 - The Dynamics of Trust in Cyberdomains.pdf:pdf},
isbn = {1541-1672 VO - 24},
issn = {1541-1672},
journal = {IEEE Intelligent Systems},
keywords = {Human-Centered Computing,online fraud,online security,resilience,resilience engineering,risk assessment,trust,trust evaluation tools,trust in automation,trust relationships},
mendeley-tags = {resilience,risk assessment},
number = {6},
pages = {5--11},
title = {{The Dynamics of Trust in Cyberdomains}},
volume = {24},
year = {2009}
}
@article{Wears2006a,
abstract = {Emergency Departments (EDs) are open systems that routinely cope with highly variable and uncertain inputs. This paper will use two critical incidents to explore worker adaptations to complexity and unpredictability, and the organizational interpretation of threats to performance. We use the concept of resilience state space and state transitions to analyse the ED’s response to chronic constraints and unexpected shocks.},
author = {Wears, R.L. and Perry, S. and McFauls, a.},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Wears, Perry, McFauls - 2006 - “ Free Fall ” – A Case Study of Resilience , Its Degradation , and Recovery in an Emergency Department.pdf:pdf},
journal = {Proceedings of the Second Symposium on Resilience Engineering},
keywords = {resilience},
mendeley-tags = {resilience},
pages = {8--10},
title = {{“ Free Fall ” – A Case Study of Resilience , Its Degradation , and Recovery in an Emergency Department}},
url = {http://www.study4me.com/body/StudyMaterial/study/Notes and PDFs/Computer Science Notes/Wears etal.pdf},
year = {2006}
}
@article{Chang2012,
abstract = {Economic recovery refers to the process by which businesses and local economies return to conditions of stability following a disaster. Its importance and complexity are being increasingly recognized in disaster risk reduction research and practice. This paper provides an overview of current research on economic recovery and suggests a research agenda to address key gaps in knowledge. Empirical studies have provided a number of robust findings on the disaster recovery of businesses and local economies, with particular insights into short- and long-term recovery patterns, influential factors in recovery, and disparities in recovery across types of businesses and economies. Modeling studies have undertaken formal analyses of economic impacts of disasters in which recovery is usually addressed through the incorporation of resilience actions and investments in repair and reconstruction. Core variables for assessing and understanding economic recovery are identified from the literature, and approaches for measuring or estimating them are discussed. The paper concludes with important gaps in the development of a robust theory of economic recovery. Systematic data collection is needed to establish patterns and variations on how well and how quickly local economies recover from disasters. Research is urgently needed on the effectiveness of resilience approaches, decisions, and policies for recovery at both the business and local economy levels. Detailed, testable theoretical frameworks will be important for advancing understanding and developing sound recovery plans and policies. It will be especially important to consider the relationship between economic recovery and recovery of the built environment and sociopolitical fabric of communities in developing a comprehensive theory of disaster recovery.},
author = {Chang, Stephanie E and Rose, Adam Z},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Chang, Rose - 2012 - Towards a Theory of Economic Recovery from Disasters.pdf:pdf},
journal = {International Journal of Mass Emergencies and Disasters},
keywords = {business,disaster recovery,economics,modeling,resilience},
mendeley-tags = {economics,resilience},
number = {2},
pages = {171--181},
title = {{Towards a Theory of Economic Recovery from Disasters}},
volume = {32},
year = {2012}
}
@article{Gordon2008,
author = {Gordon, Daniel I and Counsel, Deputy General},
file = {:D$\backslash$:/Mendeley/Gordon, Counsel - 2008 - AIR FORCE Aerial Refueling Tanker Protest AIR FORCE PROCUREMENT H ighlights.pdf:pdf},
title = {{AIR FORCE Aerial Refueling Tanker Protest AIR FORCE PROCUREMENT H ighlights}},
year = {2008}
}
@article{Jones2006,
abstract = {This paper examines the crack growth history of a range of test specimens, and cracks repaired with a composite patch, and shows that in the low to mid range ??K region there is a near linear relationship between the log of the crack length and the number of cycles. A simple methodology for predicting crack growth is then presented and validated by comparison with a range of experimental studies. ?? 2006.},
author = {Jones, R. and Krishnapillai, K. and Pitt, S.},
doi = {10.1016/j.tafmec.2006.02.001},
file = {:D$\backslash$:/Mendeley/Jones, Krishnapillai, Pitt - 2006 - Crack patching Predicting fatigue crack growth.pdf:pdf},
issn = {01678442},
journal = {Theoretical and Applied Fracture Mechanics},
keywords = {Composite repairs,Crack growth modelling,Fatigue},
number = {2},
pages = {79--91},
title = {{Crack patching: Predicting fatigue crack growth}},
volume = {45},
year = {2006}
}
@article{Herrera2006,
abstract = {The paper is based on the experience from the development and application of safety performance indicators made in cooperation with the Norwegian and Swedish Civil Aviation Authorities. The following, two main categories of safety performance indicators are discussed: outcome-based indicators (reactive indicators; measuring the outcome/ result after a loss has happened) and activity-based indicators (proactive indicators; measuring efforts to prevent accidents). The paper presents a summary of the application of safety performance indicators to assess the management of safety in aviation maintenance. Lessons learned regarding the utilization of these safety performance indicators are presented. The paper looks critically into how the indicators are used and the conclusions that may be achieved. The paper will look into safety performance indicators and how they can contribute as indicators for resilience},
author = {Herrera, Ivonne Andrade and Tinmannsvik, Ranveig Kviseth},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Herrera, Tinmannsvik - 2006 - Key elements to avoid drifting out of the safety space.pdf:pdf},
journal = {2nd Resilience Engineering International Symposium},
keywords = {measurement,resilience},
mendeley-tags = {measurement,resilience},
title = {{Key elements to avoid drifting out of the safety space}},
url = {https://docs.google.com/a/wmu.se/file/d/0B2lfx\_f4ofuXcmZBRlNrdjIxdGc/edit?usp=sharing},
year = {2006}
}
@article{Wears2007,
abstract = {Emergency Departments (EDs) are open systems that routinely cope with highly variable and uncertain inputs. This paper will use two critical incidents to explore system adaptations to demand, complexity, unpredictability, and other threats to performance. We then relate the observations to three recently proposed graphical representations of organizational resilience: the resilience state space model; the stress-strain model of adaptation; and a dynamic model of resilience. We use these graphics to analyze the ED's response to chronic constraints and unexpected shocks. The models are found to be mutually reinforcing - each highlights some important aspects of resilience, while none capture all of the salient features.},
author = {Wears, R. L. and Perry, S. J. and McFauls, a.},
doi = {10.1177/154193120705101102},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Wears, Perry, McFauls - 2007 - Dynamic Changes in Reliability and Resilience in the Emergency Department.pdf:pdf},
isbn = {9781605600376},
issn = {1071-1813},
journal = {Proceedings of the Human Factors and Ergonomics Society Annual Meeting},
keywords = {resilience},
mendeley-tags = {resilience},
number = {11},
pages = {612--616},
title = {{Dynamic Changes in Reliability and Resilience in the Emergency Department}},
volume = {51},
year = {2007}
}
@article{Scott2009,
abstract = {Architectural tactics are fundamental design decisions. They are the building blocks for both architectural design and analysis. A catalog of architectural tactics has now been in use for several years in academia and industry. This report illustrates the use of this catalog in industrial applications, describing how tactics can be used in both design and analysis. The report further shows how the needs of practice have caused the catalog of availability tactics to be updated, but demonstrates that the underlying structure of the tactics categorization has remained stable. Finally, a real-world example is provided of the application of the updated set of availability tactics, showing how it illuminates design decisions, as guided by associated heuristics and analytic models.},
author = {Scott, James and Corporation, Boeing},
file = {:D$\backslash$:/Mendeley/Scott, Corporation - 2009 - Realizing and Refining Architectural Tactics Availability.pdf:pdf},
journal = {Solutions},
number = {August},
title = {{Realizing and Refining Architectural Tactics : Availability}},
year = {2009}
}
@article{Dijkstra2006,
author = {Dijkstra, Arthur},
file = {:D$\backslash$:/Mendeley/Dijkstra Resilience and SMS.pdf:pdf},
journal = {Proceedings of the Second Resilience Engineering Symposium},
pages = {92--104},
title = {{Resilience Engineering and Safety Management Systems in aviation}},
year = {2006}
}
@article{Cabon2008,
abstract = {This paper presents the outlines of the STARE project that aims at developing the basis of a Fatigue Risk Management System (FRMS) that will enable the French regional airlines to comply with the new European regulation on flight and duty time limitations. More specifically, the new regulation requires for an operator to implement a FRMS in the case of reduced rests. The FRMS is a data-driven system integrated in the future Safety Management System (SMS) of the airline. The whole process of the FRMS is described, including the use of predictive models of fatigue, a systematic and focused monitoring. The principles of the FRMS are discussed with regards to resilience engineering.},
author = {Cabon, P. and Mollard, R.},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Cabon, Mollard - 2008 - From flight time limitations to Fatigue Risk Management Systems.pdf:pdf},
isbn = {9781409410355},
journal = {Proceedings of the \ldots},
keywords = {resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
title = {{From flight time limitations to Fatigue Risk Management Systems}},
url = {http://books.google.com/books?hl=en\&lr=\&id=8-j4Crhb3vwC\&oi=fnd\&pg=PA27\&dq=From+Flight+Time+Limitations+to+Fatigue+Risk+Management+Systems\&ots=FA7w5O02MT\&sig=T5Vj-d\_bJVhuKgN-z1RNwwFsxFc},
year = {2008}
}
@article{Woods,
author = {Woods, David D and Herrera, Ivonne and Woltjer, Rogier},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Woods, Herrera, Woltjer - Unknown - Iden \% fying Imbalances in a Por4olio of Safety Metrics The Q4- ­ ‐ Balance Framework for Economy-.pdf:pdf},
keywords = {measurement,resilience},
mendeley-tags = {measurement,resilience},
title = {{Iden \% fying Imbalances in a Por4olio of Safety Metrics : The Q4- ­ ‐ Balance Framework for Economy- ­ ‐ Safety Tradeoffs 1 PROACTIVE SAFETY METRICS IN AVIATION 2 BALANCING ECONOMY- ­ ‐ SAFETY TRADEOFFS : THE Q4 FRAMEWORK}}
}
@article{Owren-wiest2008,
author = {Owren-wiest, Nicole J and Sacilotto, Kara M and Wishart, Nicole P},
file = {:D$\backslash$:/Mendeley/Owren-wiest, Sacilotto, Wishart - 2008 - Matter of File Date.pdf:pdf},
journal = {Office},
pages = {1--67},
title = {{Matter of : File : Date :}},
year = {2008}
}
@article{Karikawa,
author = {Karikawa, Daisuke and Aoyama, Hisae and Takahashi, Makoto and Furuta, Kazuo and Ishibashi, Akira},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Karikawa et al. - Unknown - A Method for Visualizing Trade-offs in En-route Air Traffic Control Tasks EN-ROUTE ATC TASKS AND TARGET SECT.pdf:pdf},
keywords = {resilience,risk assessment},
mendeley-tags = {resilience,risk assessment},
title = {{A Method for Visualizing Trade-offs in En-route Air Traffic Control Tasks EN-ROUTE ATC TASKS AND TARGET SECTOR}}
}
@article{Herrera2008,
abstract = {This paper explores the identification of leading indicators in aviation maintenance. Traditionally, improvements in aviation have been based on incident reporting and analyses and learning from failures. This traditional approach measures safety performance based on lagging indicators. However, there is a growing concern that this information does not provide the requisite information and insight to prevent future accidents. Resilience has been identified as the ability of the system to adjust prior, during and after a major mishap. This implies a need to recognize early signals to be able to anticipate and act properly. The objective of the paper is to understand leading indicators and the “why” behind the leading indicator as basis to look forward in monitoring safety performance. With regard to the leading indicator definition applied to aviation and maintenance in the context of resilience, we focus on learning from success and failures and propose: Leading indicators are precursors based on a model of safety implying a significant possibility of a subsequent event that has an impact on safety and performance. Leading indicators can therefore provide information about changes in risk before traditional risk analyses are able to capture this change},
author = {Herrera, Ivonne Andrade and Hovden, J},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Herrera, Hovden - 2008 - Leading indicators applied to maintenance in the framework of resilience engineering A conceptual approach.pdf:pdf},
journal = {3rd Resilience Engineering Symposium},
keywords = {measurement,resilience},
mendeley-tags = {measurement,resilience},
number = {October},
pages = {28--30 October},
title = {{Leading indicators applied to maintenance in the framework of resilience engineering : A conceptual approach}},
year = {2008}
}
@article{Edelman2004,
author = {Edelman, Alan},
file = {:D$\backslash$:/Mendeley/Edelman - 2004 - Why are random matrix.pdf:pdf},
journal = {Science},
title = {{Why are random matrix}},
year = {2004}
}
@article{Stephens2011,
abstract = {Abstract. One strategy that systems employ to remain resilient in the face of shifting demands is the creation and maintenance of marginsof maneuver, cushions of potential actions and additional resources that allows the system to continue functioning despite unexpected demands. Systems are often comprised of units which have partial authority and autonomy to manage their individual margins of maneuver. In a study of emergency department interactions with other hospital units, we found that reorganizations to maintain margin could be classified into one of three categories: units could either defensively restrict the actions of other units or borrow margin from them, autonomously reorganize to create new margin, or cooperatively act with other units to exploit existing common pool resources and create new ones. The enumeration of the three classes of strategies to maintain margin of maneuver further explains how systems could reorganize themselves to remain resilient, and how they become brittle and fail. The influences on and interactions of each type of strategy are explored, and directions for future research to allow for better control of overall system margin, and hence resilience, are discussed.},
author = {Stephens, R J and Woods, D and Branlat, M and Wears, R L},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Stephens et al. - 2011 - Colliding Dilemmas Interactions of Locally Adaptive Strategies in a Hospital Setting.pdf:pdf},
journal = {Fourth Symposium on Resilience Engineering},
keywords = {resilience},
mendeley-tags = {resilience},
title = {{Colliding Dilemmas: Interactions of Locally Adaptive Strategies in a Hospital Setting}},
year = {2011}
}
@article{Bouali2012,
abstract = {Embedded systems development creates a need of new design, verification and validation technics. Formal methods appear as a very interesting approach for embedded systems analysis, especially for dependability studies. The chosen formalism for this work is based on Colored Petri Net (CPN) for two main reasons: the expressivity and the formal nature. Also, they model easily the static and the dynamic natures of the studied systems. The main challenge of this work is to use existing models, which describe the system structure and/or behavior, to extract the dependability information in a most general case and failure diagnosis information in a particular case. The proposed approach is a CPN structural backward reachability analysis. It can be split into two parts. The first one is to perform the proposed analysis: inverse CPN. It is obtained thanks to structural transformations applied on the original CPN. The second part is the analysis implementation. This part needs some complementary concepts. Among them, the most important is the marking enhancement. The proposed approach is studied under two complementary aspects: algorithmic and theoretic aspects. The first one proposes transformations for the CPN inversion and the analysis implementation. The second aspect (the theoretical one) aims to offer a formal proof for the approach by applying two methods which are linear algebra and Linear Logic. ?? 2011 Elsevier Ltd All rights reserved.},
author = {Bouali, Mohamed and Barger, Pavol and Schon, Walter},
doi = {10.1016/j.ress.2011.10.003},
file = {:D$\backslash$:/Mendeley/Bouali, Barger, Schon - 2012 - Backward reachability of Colored Petri Nets for systems diagnosis.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering and System Safety},
keywords = {Backward reachability,Colored Petri Nets (CPN),Dependability,Diagnosis,Embedded systems,Structural analysis},
pages = {1--14},
publisher = {Elsevier},
title = {{Backward reachability of Colored Petri Nets for systems diagnosis}},
url = {http://dx.doi.org/10.1016/j.ress.2011.10.003},
volume = {99},
year = {2012}
}
@article{Debbah2008,
author = {Debbah, Merouane M\'{e}rouane and Debbah, Prof M\'{e}rouane},
file = {:D$\backslash$:/Mendeley/Tulino - 2006 - Random Matrix Theory for Wirelesss Communications.pdf:pdf},
keywords = {alcatel-lucent chair on flexible,dom matrix theory for,m\'{e}rouane debbah,prof,radio,wireless communications},
title = {{Random Matrix Theory for Wireless Communications}},
url = {http://www.supelec.fr},
year = {2008}
}
@article{Costella2009,
abstract = {This article introduces a method for assessing health and safety management systems (MAHS) that has two innovative characteristics: (a) it brings together the three main auditing approaches to health and safety (HS) - the structural approach (which assesses the system prescribed), the operational approach (which assesses what is really happening on the shop-floor) and the performance approach (which assesses the results of performance indicators); (b) it emphasizes the resilience engineering perspective on HS, which takes into consideration four major principles (flexibility, learning, awareness, and top management commitment). Such principles underlie seven major assessment criteria, which in turn are divided into items (e.g. hazard identification from a resilience perspective is an item that belongs to the criteria of production processes). The items are sub-divided into statements, which are the requirements that should be assessed based on interviews, analysis of documents and direct observations. Within the 112 requirements proposed, 38 of them have clear links with at least one out of the four resilience engineering principles adopted. The remaining requirements are based on traditional assumptions underlying the so-called best practices of HS management. The results of the assessment for each item are expressed by a score on a scale of compliance with the established requirements, ranging from 0\% to 100\%. The specific score within that scale is obtained from tables used to assess applications for the Brazilian national quality award. The MAHS was tested in a case study that was carried out in a factory that manufactures automobile exhaust systems, located in Brazil. © 2008 Elsevier Ltd. All rights reserved.},
author = {Costella, Marcelo Fabiano and Saurin, Tarcisio Abreu and {de Macedo Guimar\~{a}es}, Lia Buarque},
doi = {10.1016/j.ssci.2008.11.006},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Costella, Saurin, de Macedo Guimar\~{a}es - 2009 - A method for assessing health and safety management systems from the resilience engineeri.pdf:pdf},
isbn = {09257535},
issn = {09257535},
journal = {Safety Science},
keywords = {Health and safety audits,Health and safety management systems,Manufacturing industry,Resilience engineering,measurement,resilience},
mendeley-tags = {measurement,resilience},
number = {8},
pages = {1056--1067},
pmid = {40633730},
publisher = {Elsevier Ltd},
title = {{A method for assessing health and safety management systems from the resilience engineering perspective}},
url = {http://dx.doi.org/10.1016/j.ssci.2008.11.006},
volume = {47},
year = {2009}
}
@article{Escobar2003,
abstract = {Degradation data analysis is a powerful tool for reliability assessment. Useful reliability information is available from degradation data when there are few or even no failures. For some applications the degradation measurement process destroys or changes the physical/mechanical characteristics of test units. In such applications, only one meaningful measurement can be can be taken on each test unit. This is known as “destructive degradation.” Degradation tests are often accelerated by testing at higher than usual levels of accelerating variables like temperature. This chapter describes an important class of models for accelerated destructive degradation data. We use likelihood-based methods for inference on both the degradation and the induced failure-time distributions. The methods are illustrated with the results of an accelerated destructive degradation test for an adhesive bond.},
author = {Escobar, L a and Meeker, W Q},
file = {:D$\backslash$:/Mendeley/Escobar et al. - Unknown - ACCELERATED DESTRUCTIVE DEGRADATION TESTS DATA , MODELS , AND ANALYSIS.pdf:pdf},
journal = {\ldots and Statistical Methods in \ldots},
pages = {1--17},
title = {{Accelerated destructive degradation tests: Data, models, and analysis}},
url = {http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.142.8991\&rep=rep1\&type=pdf},
year = {2003}
}
@article{Pflanz2012,
abstract = {From a national defense, as well as a civilian infrastructure perspective, a need exists to design and develop systems resilient to disruption. Disruptions are often difficult to predict or may be potentially unavoidable. Systems able to survive and recover from disruption are referred to as resilient. In the case of mission critical systems, such as command and control systems, resilience is a necessary characteristic and must be considered early in the development cycle. This paper describes a quantitative approach to evaluating the expected resilience of a command and control system. The approach uses a Petri Net based executable model of the system architecture. The rigorous graph-theoretic and executable properties of Petri Nets are leveraged to support static and dynamic measures of the attributes of resilience. These measures are then combined into a holistic evaluation of resilience for the command and control system under study. The evaluation results can then be used to support selection among alternative candidate architectures and to identify areas for improvement in the selected architecture. ?? 2012 Published by Elsevier Ltd.},
author = {Pflanz, Mark and Levis, Alexander},
doi = {10.1016/j.procs.2012.01.030},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Pflanz, Levis - 2012 - An approach to evaluating resilience in command and control architectures.pdf:pdf},
issn = {18770509},
journal = {Procedia Computer Science},
keywords = {Capability,Command and control,Disruption,Executable architecture models,Petri Nets,Resilience,measurement,resilience},
mendeley-tags = {measurement,resilience},
pages = {141--146},
title = {{An approach to evaluating resilience in command and control architectures}},
url = {http://dx.doi.org/10.1016/j.procs.2012.01.030},
volume = {8},
year = {2012}
}
@article{Emanuel2012a,
author = {Emanuel, Roy},
file = {:D$\backslash$:/Mendeley/Emanuel - 2012 - Paperclip Experiment.pdf:pdf},
pages = {1--20},
title = {{Paperclip Experiment}},
year = {2012}
}
@article{Pugno2005a,
abstract = {This paper presents a novel experimental-theoretical method to investigate the strength of structures having complex geometries, which are commonly used in microelectromechanical systems (MEMS). It involves the stretching to failure of freestanding thin-film membranes, in a fixed-fixed configuration, containing micro-fabricated sharp cracks, blunt notches and re-entrant corners. The defects, made by nanoindentation and focused ion beam milling, are characterized by scanning electron microscopy (SEM). MEMS structures made of ultra-nano-crystalline-diamond (UNCD), a material developed at Argonne National Laboratory, were investigated using this methodology. A theory to predict the strength of microstructures with defects is proposed and compared with experimental results. It is shown that fracture mechanics general concepts can be applied with confidence in the design of MEMS. An experimental methodology and formulas to predict strength of MEMS structures possessing defects of various geometries are provided. © 2004 Elsevier Ltd. All rights reserved.},
author = {Pugno, N. and Peng, B. and Espinosa, H. D.},
doi = {10.1016/j.ijsolstr.2004.06.026},
file = {:D$\backslash$:/Mendeley/Pugno, Peng, Espinosa - 2005 - Predictions of strength in MEMS components with defectsa novel experimentaltheoretical approach.pdf:pdf},
issn = {00207683},
journal = {International Journal of Solids and Structures},
keywords = {Brittle materials,Fracture,MEMS,Strength,Thin films},
number = {2},
pages = {647--661},
pmid = {170},
title = {{Predictions of strength in MEMS components with defects - A novel experimental-theoretical approach}},
volume = {42},
year = {2005}
}
@unpublished{Taleb2015,
author = {Taleb, Nassim Nicholas},
file = {:D$\backslash$:/Mendeley/Taleb - Unknown - Silent risk.pdf:pdf},
institution = {Descartes},
number = {August 2014},
pages = {441},
title = {{Silent Risk}},
year = {2015}
}
@article{Xu2006,
abstract = {A new approach is proposed based on box-counting method to estimate the fractal dimensions, D2d and D3d of corrosion images. They denote two-dimensional (2D) and three-dimensional (3D) characteristics of corroded surface morphology. The results have been tested through dealing with classical fractal figures, pit morphology of moon surface and practical corroded samples etc. to show that this new method is computationally simple, convenient and accurate. More specially, D2d and D3d have definite corrosion expressions, which respectively denote the fractal dimensions for pit diameter distribution and pit depth distribution on real corroded surface. ?? 2006 Elsevier B.V. All rights reserved.},
author = {Xu, Shujian and Weng, Yongji},
doi = {10.1016/j.patrec.2006.05.005},
file = {:D$\backslash$:/Mendeley/Xu, Weng - 2006 - A new approach to estimate fractal dimensions of corrosion images.pdf:pdf},
issn = {01678655},
journal = {Pattern Recognition Letters},
keywords = {Corrosion image,FD determination,Image FD,Pit depth distribution,Pit diameter distribution,Relativity analysis},
number = {16},
pages = {1942--1947},
title = {{A new approach to estimate fractal dimensions of corrosion images}},
volume = {27},
year = {2006}
}
@article{Carlile2005,
abstract = {Some scholars of organization and strategy expend significant energy disparaging and defending various research methods. Debates about deductive versus inductive theory-building and the objectivity of information from field observation versus that of large-sample numerical data are dichotomies that surface frequently in our lives and those of our students. Despite this focus, some of the most respected members of our research profession (i.e., Simon (1976), Solow (1985), Hambrick (1994), Staw and Sutton (1995), and Hayes (2002)) have continued to express concerns that the collective efforts of business academics have produced a paucity of theory that is intellectually rigorous, practically useful, and able to stand the tests of time and changing circumstances. The purpose of this paper is to outline a process of theory building that links questions about data, methods and theory. We hope that this model can provide a common language about the research process that helps scholars of management better understand the roles of different types of data and research, and thereby to build more effectively on each others work. Our unit of analysis is at two levels: the individual research project and the iterative cycles of theory building in which a researchers attempt to build upon each others work. The model synthesizes and augments other studies of how communities of scholars cumulatively build valid and reliable theory.1 It has normative and pedagogical implications for how we conduct research, evaluate the work of others, train our doctoral students, and design our courses.},
author = {Carlile, Paul R and Christensen, Clayton M},
doi = {10.1080/02815738808730154},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Carlile, Christensen - 2005 - The Cycles of Theory Building in Management Research The Cycles of Theory Building in Management Research.pdf:pdf},
journal = {Building},
keywords = {resilience,theory building},
mendeley-tags = {resilience,theory building},
number = {January 6},
pages = {0--24},
title = {{The Cycles of Theory Building in Management Research The Cycles of Theory Building in Management Research}},
url = {http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.136.8158},
volume = {05-057},
year = {2005}
}
@article{Zachary2012,
author = {Zachary, Wayne and Techologies, C M Z Health and Crandall, Beth and Miller, Tom and Nemeth, Christopher},
file = {:C$\backslash$:/Users/Roy/AppData/Local/Mendeley Ltd./Mendeley Desktop/Downloaded/Zachary et al. - 2012 - R - I C ER RE “ Rapidized ” Cognitive Task Analysis.pdf:pdf},
number = {aprIL},
pages = {61--67},
title = {{R - I C ER RE “ Rapidized ” Cognitive Task Analysis}},
url = {resilience; risk assessment},
year = {2012}
}
@article{Software1866,
author = {Software, Golden},
file = {:D$\backslash$:/Mendeley/Software - 1866 - Getting Started Guide.pdf:pdf},
journal = {Options},
keywords = {Getting Started Guide,Golden Software,Grapher},
number = {July},
title = {{Getting Started Guide}},
year = {1866}
}
@book{ScottJack,
address = {Hoboken},
author = {Jackson, Scott},
isbn = {978-0-470-40503-1},
publisher = {John Wiley \& Sons, Inc},
title = {{Architecting Resilient Systems: Accident Avoidance and Survival and Recovery from Disruptions}},
year = {2010}
}
@article{Dekker1996,
author = {Dekker, Rommert},
doi = {10.1016/0951-8320(95)00076-3},
file = {:D$\backslash$:/Mendeley/Dekker - 1996 - Applications of maintenance optimization models a review and analysis.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
month = mar,
number = {3},
pages = {229--240},
title = {{Applications of maintenance optimization models: a review and analysis}},
url = {http://linkinghub.elsevier.com/retrieve/pii/0951832095000763},
volume = {51},
year = {1996}
}
@article{Gao2013,
author = {Gao, Xing and Zhong, Weijun and Mei, Shue},
doi = {10.1016/j.ress.2013.05.004},
file = {:D$\backslash$:/Mendeley/Gao, Zhong, Mei - 2013 - A game-theory approach to configuration of detection software with decision errors(2).pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
keywords = {Decision errors,Detection software,Game-theory,Intrusion detection systems},
month = nov,
pages = {35--43},
publisher = {Elsevier},
title = {{A game-theory approach to configuration of detection software with decision errors}},
url = {http://linkinghub.elsevier.com/retrieve/pii/S0951832013001294},
volume = {119},
year = {2013}
}
@article{Zaaijer2009,
author = {Zaaijer, M.B.},
doi = {10.1002/we.349},
file = {:D$\backslash$:/Mendeley/Zaaijer - 2009 - Review of knowledge development for the design of offshore wind energy technology.pdf:pdf},
issn = {10954244},
journal = {Wind Energy},
month = jul,
number = {5},
pages = {411--430},
title = {{Review of knowledge development for the design of offshore wind energy technology}},
url = {http://doi.wiley.com/10.1002/we.349},
volume = {12},
year = {2009}
}
@article{Borges2012,
abstract = {Into dangerous and complex systems with high degree of interactivity between its components, the variability is present at all time, demanding a high degree of control of its operation. Maintaining or recovering the normality, when the system is under some stress (instability) is a function of Resilience. To cope with prevention, forecast, recovery and with memory of experiences from learned lessons requires some features from the companies. This paper purposes a structure that enables the Total Resilience of a system production that defines the assignments for Workers, Designers and Management Team, according to its features and possibilities. During one year and a half developing studies on ergonomics area of a Brazilian Oil Refinery, several situations were observed and studied using Work Ergonomic Analysis. These situations show actions and strategies that workers use to maintain the system stability. Furthermore, they revealed the importance that these actions are stored in a database of learned lessons from the Company. The research resulted in a broad scheme. It places each of these groups in the process of Total Resilience. It also shows the human like a center of actions that ensure the continuity of the system, main element at Resilience (Anthropocentric View).},
author = {Borges, F\'{a}bio Morais and Menegon, Nilton Luiz},
doi = {10.3233/WOR-2012-0589-3238},
file = {:D$\backslash$:/Mendeley/Borges, Menegon - 2012 - Different roles in the quest for system resilience.pdf:pdf},
issn = {1875-9270},
journal = {Work (Reading, Mass.)},
keywords = {Brazil,Decision Making,Equipment Design,Equipment Failure Analysis,Extraction and Processing Industry,Extraction and Processing Industry: instrumentatio,Extraction and Processing Industry: organization \&,Human Engineering,Humans,Man-Machine Systems,Problem-Based Learning,Professional Role},
month = jan,
pages = {3238--45},
pmid = {22317211},
title = {{Different roles in the quest for system resilience.}},
url = {http://www.ncbi.nlm.nih.gov/pubmed/22317211},
volume = {41 Suppl 1},
year = {2012}
}
@article{Aven2011d,
author = {Aven, T.},
doi = {10.1016/j.ress.2010.11.004},
file = {:D$\backslash$:/Mendeley/Aven - 2011 - Interpretations of alternative uncertainty representations in a reliability and risk analysis context.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
keywords = {Evidence theory,Fuzzy probability,Imprecise (interval) probability,Interpretation,Possibility theory,Risk and reliability analysis,Subjective probabilities,Uncertainties},
month = mar,
number = {3},
pages = {353--360},
publisher = {Elsevier},
title = {{Interpretations of alternative uncertainty representations in a reliability and risk analysis context}},
url = {http://linkinghub.elsevier.com/retrieve/pii/S0951832010002449},
volume = {96},
year = {2011}
}
@article{Jiang2013,
author = {Jiang, Xiaomo and Yuan, Yong and Liu, Xian},
doi = {10.1016/j.ress.2012.11.006},
file = {:D$\backslash$:/Mendeley/Jiang, Yuan, Liu - 2013 - Bayesian inference method for stochastic damage accumulation modeling.pdf:pdf},
issn = {09518320},
journal = {Reliability Engineering \& System Safety},
keywords = {Bayesian inference,Box–Cox transformation,CBM,Damage accumulation model,Model validation,Proportional hazard model},
month = mar,
pages = {126--138},
publisher = {Elsevier},
title = {{Bayesian inference method for stochastic damage accumulation modeling}},
url = {http://linkinghub.elsevier.com/retrieve/pii/S0951832012002359},
volume = {111},
year = {2013}
}
         -->
# Out:
#   File "<ipython-input-1-58d7be4b18eb>", line 1
#     <!--bibtex
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #References
